# %% [markdown]
# # **INSTALAR REPOSITORIOS NECESARIOS**

# %%
#anaconda prompt > pip install selenium
#anaconda prompt > conda install -c anaconda openpyxl

from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys

import openpyxl
import time
import os
import base64

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ***FUNCIONES***

# %%
def siguiente_conteo(location, sku, driver, delay): #REVISAR FUNCION
    """tocar CC1, From LOC y SKU e introducir el codigo"""

    try:
        WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "//*[@id='UserId']")))
    
   
    except TimeoutError:
        print("Tarda demasiado")

    var_loc = location
    var_sku = sku
    try:
        #cycc1
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[1]/button/span/span").click()
        time.sleep(1)
        #from loc
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[2]/div/mat-button-toggle[1]/button/span/span").click()
        time.sleep(1)
        #sku
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[2]/div/mat-button-toggle[3]/button/span/span").click()
        time.sleep(1)
        #client ID
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[1]/mat-form-field/div/div[1]/div/mat-select/div/div[2]").click()
        driver.find_element("xpath", "/html/body/div[2]/div[2]/div/div/div/mat-option[2]/span").click()
        time.sleep(1)
        #SKU text
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[2]/mat-form-field/div/div[1]/div/input").send_keys(var_sku)
        time.sleep(1)
        #Loc text
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[3]/mat-form-field/div/div[1]/div/input").send_keys(var_loc)
        time.sleep(1)
        #Search
        time.sleep(1)
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[4]/button/span[1]").click()


    except:
        try:
            try:
                WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[1]/div[1]/mat-form-field/div/div[1]/div/input")))
                
            
            except TimeoutError:
                print("Tarda demasiado")



            #Cogemos valores de la pagina
            location = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[1]/div[2]/span").text
            sku_count = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[2]/div[2]/span") .text

            #los introducimos en los campos
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[1]/div[1]/mat-form-field/div/div[1]/div/input").send_keys(location)
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[1]/div[2]/mat-form-field/div/div[1]/div/input").send_keys(sku_count)

            #confirmamos
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[2]/div[1]/button").click()

            
        except:
            #Complete LOT Count
            try:
                WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/form/div[4]/div[2]/button")))
                
            
            except TimeoutError:
                print("Tarda demasiado")
                
                
                
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/form/div[4]/div[2]/button").click()


def fill_key_list(first_sku_row, row_limit, sku_col, location_col, lpn_col, batch_col, qty_col):
    """Creamos una funcion que añada una clave unica y lo corresponda a un valor"""
    key_list={}
                
    for i in range(first_sku_row, row_limit + 1):
        sku = sheet_obj.cell(row = i, column = sku_col).value
        loc = sheet_obj.cell(row = i, column = location_col).value
        lpn = sheet_obj.cell(row = i, column = lpn_col).value
        batch = sheet_obj.cell(row =i, column = batch_col).value
        value = sheet_obj.cell(row = i, column = qty_col).value

        if lpn == None:
            lpn_check = ""
                    
        if (not is_number(lpn)) or lpn == None:
            lpn_check = lpn
                        #print(lpn_check)
                        
        if is_number(lpn):
            lpn_check = str(lpn).zfill(10)
            #print(lpn_check)
                    
        if lpn_check == None:
            lpn_check = ""
                        
        if batch == None:
            batch = ""

        #print(("EXCEL -> SKU: {} Len: {}").format(sku, len(sku)))
        #print(("EXCEL -> LOC: {} Len: {}").format(loc, len(loc)))
        #print(("EXCEL -> LPN: {} Len: {}").format(lpn_check, len(lpn_check)))
        #print(("EXCEL -> Batch: {} Len: {}").format(batch, len(batch)))
        #print(("EXCEL -> QTY: {} \n").format(value))
         #key_loc+key_sku+key_batch+key_lot+key_lpn

        keys_fan = str(loc+sku+batch+lpn_check)
        key_list.setdefault(keys_fan, value)
    
    return key_list

def pasar_sku(lista, first_sku_row, row_limit,check_col):
    """para pasar de un sku finalizado a otro que todavía no hayamos realizado"""
    
    for i in range(first_sku_row, row_limit+1):
        check = sheet_obj.cell(row = i, column = check_col).value
        
        print(("CHECK: {} I: {}").format(check, (i)))
        if check != "Y":
            return lista[i+1]
         
        else:
            pass



def change_location(sku_item, location):
    """confirmar cambios de ubicacion"""
    print("change location")
    loc_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[1]/div[2]/span").text
    sku_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[2]/div[2]/span").text
    print("location url: " + loc_url + " location: " + location)
    #print("sku url: "+ sku_url + " sku: " + sku_item)
    
    
    if location == loc_url:
        if sku_item == sku_url:
            driver.find_element("xpath", "//*[@id='skuConf']").send_keys(sku_item)
            time.sleep(3)
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[2]/div[1]/button/span[1]").click()
    time.sleep(5)        
            

  

def is_number(lpn):
    """saber si es un numero o no"""
    if lpn == None:
        lpn = ""  
    
    try:
        int(lpn)
    except ValueError:
        return False
    return True

   
def test_check(first_sku, row_limit, check_col):
    
    result = 0
    
    for i in range(first_sku, row_limit + 1):
        
        check = sheet_obj.cell(row =i, column = check_col).value
        
        if check == "Y":
            result += 1
    
    return result



def fill_sku_list(first_sku_row, article_col, row_limit):
    """Cargar una lista con todos los Sku"""
    fill_list= []
    for name in range(first_sku_row, row_limit+1):
        fill_list.append(sheet_obj.cell(row=name, column=article_col).value)
        fill_list = list(dict.fromkeys(fill_list))
    #print(*fill_list, sep=", ")
    return fill_list


def list_sku_terminated(sku):
    """añadir sku por terminados"""
    sku_terminated = []
    sku_terminated.append(sku)
    #print(sku_terminated)
    return sku_terminated



def busqueda_binaria_recursiva(lista, key, left, right):
    """Funcion para buscar un elemento en una lista ordenada mediante busqueda binaria"""
    if left > right:
        return -1
    middlepos = (left + right) // 2
    middle = lista[middlepos]
    if middle == key:
        print(("MIDLE=KEY BBINARIA: {}").format(middlepos))
        return middlepos
    if key < middle:
        print(("KEY<MIDDLE MEDIA BBINARIA: {}").format(middlepos))
        return (middlepos - 1)
    else:
        print(("KEY > MIDDLE MEDIA BBINARIA: {}").format(middlepos))
        return(middlepos + 1)
# Out:
#   File "C:\Users\jgmeras\AppData\Local\Temp\ipykernel_18320\1113082765.py", line 76
#     def fill_key_list(first_sku_row, row_limit, sku_col, location_col, lpn_col, batch_col, qty_col):
#                                                                                                     ^
# IndentationError: unexpected unindent

# %% [markdown]
# # **CONFIGURAMOS EL NAVEGADOR**

# %%
# *****URL DE PRUEBAS *****
url = "http://m.mad001.qa.wmx.sc.xpo.com" 

# ****** URL DE PRODUCCION ******
#url = "http://m.mad001.wmx.sc.xpo.com"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver_options = Options()
driver_options.add_argument(headers)
driver_options.add_argument('--no-sandbox')

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
#driver.execute_script("window.scrollTo(500, 1080);")

# %% [markdown]
# # **LOGUEAR**

# %%
decoded_user = base64.b64decode("anBhbGFjaW9z")
decoded_pw = base64.b64decode("UnVtcGVsc3Rpbmt5ODIk")
delay = 20 #seconds

user = decoded_user.decode("utf-8")
passw = decoded_pw.decode("utf-8")

try:
    myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "//*[@id='UserId']")))
    
   
except TimeoutError:
    print("Tarda demasiado")

user_login = driver.find_element("xpath", "//*[@id='UserId']").send_keys(user)
user_passw = driver.find_element("xpath", "//*[@id='Psw']").send_keys(passw)
user_passw = driver.find_element("xpath", "//*[@id='Psw']").send_keys(Keys.RETURN)

# %% [markdown]
# # ***acceder al menú de conteo ciclico***

# %%
try:
    myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon")))
    
   
except TimeoutError:
    print("Tarda demasiado")



#tocar boton 3 rayas
wmx_menu = driver.find_element("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon").click()

time.sleep(2)

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[4]/a/span[2]").click()

time.sleep(2)

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[4]/div/a[6]/span[2]").click()

time.sleep(2)

# %% [markdown]
# # **PREPARAR EXCEL (SIEMPRE TENERLO CERRADO)**

# %% [markdown]
# # **RECORDAR BUSCAR EN INV BALANCE EL SKU Y RELLENAR EL EXCEL**
# # **MUY IMPORTANTE: QUITAR ESPACIOS EN BLANCO**

# %%
#Incluir la localizacion del fichero excel con los datos
current_directory = os.getcwd()
path = current_directory + "\AvonCCycle.xlsx"


# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path, data_only=True)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column

print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)
print("Proceso de preparacion de Excel finalizado")

#Introducir el numero de columna en la que se encuentra el SKU (A=1, B=2, C=3...)
sku_col = 4

#Introducir el numero de la fila en la que se encuentra el primer valor de SKU
first_sku_row = 2

#Introducir el numero de columna en la que se encuentra la cantidad a introducir
cantidad_col = 5

#Introducir el numero de columna en el que se encuentra la ubicacion
location_col = 2

#Introducir numero de columna en el que se encuentra el lote
batch_col = 8

#Introducir numero de columna de verificación
check_col= 9

#Introducir numero de columna de LPN
lpn_col = 3

#Introducir numero de columna de clave
key_col = 10


time.sleep(3)

# %% [markdown]
# # **LECTURA Y ESCRITURA EN WEB**

# %%
#creamos el bucle para que vaya leyendo del excel y rellene el formulario
var_loc = sheet_obj.cell(row = first_sku_row, column = location_col).value
result = 0


while result < row_limit+1:

    print(("RESULT: {} / {}").format(result, row_limit+1))  
    try:
        ch1 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[1]/button/span/span").text
        ch2 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[2]/button/span/span").text
        ch3 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[3]/button/span/span").text
        check = ch1+ch2+ch3
        
        if check == "CYCC1CYCC2CYCC3":
            #Comprobamos como va la lista para continuar o parar:
            #primera pantalla           
            list2 = []
            listresult =[]

            list1 = fill_sku_list(first_sku_row, sku_col, row_limit)

            
            for name in range(first_sku_row, row_limit+1):
                list2 = list_sku_terminated(sheet_obj.cell(row=name, column=sku_col).value)
                for item in list2:
                    if item not in listresult:
                        listresult.append(item)

            ult_sku = pasar_sku(list1, first_sku_row, row_limit, check_col)

            
            print(("{}: {}").format(name, ult_sku))
            
            siguiente_conteo(var_loc, ult_sku, driver, delay)
            
    
                
    except:
        try:
            
            #Creamos una clave desde la URL
            try:
                myElem = WebDriverWait(driver, delay).until(EC.presence_of_element_located(("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[2]/div[2]/span")))
        
    
            except TimeoutError:
                print("Tarda demasiado")


            key_loc = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[2]/div[2]/span").text
            key_sku = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[3]/div[2]/span").text
            key_batch = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[4]/div[2]/span").text
            key_lpn = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[17]/div[2]/span").text

            #formateamos la cadena lpn para evitar discrepancias
            if key_lpn == None:
                lpn_check = ""
                        
            if (not is_number(key_lpn)) or key_lpn == None:
                lpn_check = key_lpn
                #print(lpn_check)
                            
            if is_number(key_lpn):
                lpn_check = str(key_lpn).zfill(10)
                #print(lpn_check)
                        
            if lpn_check == None:
                lpn_check = ""
                            
            if batch == None:
                batch = ""
            
            #print(("URL ->SKU: {} Len: {}").format(key_sku, len(key_sku)))
            #print(("URL ->LOC: {} Len: {}").format(key_loc, len(key_loc)))
            #print(("URL ->LPN: {} Len: {}").format(lpn_check, len(lpn_check)))
            #print(("URL ->Batch: {} Len: {}\n").format(key_batch, len(key_batch)))

            master_key = str(key_loc+key_sku+key_batch+lpn_check)
            
            #Creamos una lista de claves desde el excel para comparar
            key_list1 = fill_key_list(first_sku_row, row_limit, sku_col, location_col, lpn_col, batch_col, cantidad_col)

            #print(("KEY: {} KEYLIST: {}\n").format(master_key, key_list1))
            
            #realizamos las busquedas
            qty = key_list1[master_key]
            
            #extraemos la cantidad de la posicion
            cant = sheet_obj.cell(row = qty, column = cantidad_col).value
            #print(("CANTIDAD {}\n").format(qty))
            #Marcamos como procesado el SKU
            sheet_obj.cell(row = qty, column= check_col).value = "Y"
            
            #Limpiamos e introducimos el valor
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").clear
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").send_keys(cant)
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[21]/button/span[1]").click()

            #comprobamos el resultado para seguir o no en el ciclo
            result = test_check(first_sku_row, row_limit, check_col)
            wb_obj.save(path)
            time.sleep(5)

        except:
            try:
                
                #pasamos al siguiente SKU y siguiente conteo
                sig_sku=pasar_sku(lista=list1,check_col=check_col)
                siguiente_conteo(var_loc, sig_sku, driver, delay) 
                time.sleep(5)
                
            except:
                pass

#result = check_list(first_sku_row, row_limit, check_col)

                
try:
    wb_obj.save(path)
except:
    print("NO SE PUDO GUARDAR EL LIBRO CON EXITO")
    
print("SCRIPT FINALIZADO CON EXITO")

# %% [markdown]
# # ***----***

# %%
listresult = []
list1 = []
key_list1 = {}
list2 = []
master = "R-21-02-00-CF1482292FV1TS"

list1 = fill_sku_list(first_sku_row, sku_col, row_limit)
key_list1 = fill_key_list(first_sku_row, row_limit, sku_col, location_col, lpn_col, batch_col, cantidad_col)
            
for name in range(first_sku_row, row_limit+1):
    list2 = list_sku_terminated(sheet_obj.cell(row=name, column=sku_col).value)
    for item in list2:
        if item not in listresult:
            listresult.append(item)
            print(("item: {}").format(item))

print(("List1: {}").format(list1))
print()
print(("List2: {}").format(list2))
print()
print(("Listresult: {}").format(listresult))
print(("Diccionario: {}").format(key_list1))
print(("solo: {}").format(key_list1[master]))
