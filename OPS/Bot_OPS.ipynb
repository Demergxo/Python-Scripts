# %% [markdown]
# # ***IMPORTAR LIBRERIAS***

# %%
#from datetime import datetime
import time
from datetime import datetime

from selenium.webdriver import Chrome
from selenium import webdriver
#from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait as wait

import random
#import re
import pandas as pd

# %% [markdown]
# # ***FUNCIONES***

# %%
def leer_csv_apc2():
    #lee el csv y devulve un diccionario con todos los valores
    
    empleado = pd.read_csv('empleados.csv', dtype='string')#na_filter=False) 
    empleado.to_dict('records')  
    
    #si ZONA esta vacio, llama la funcion para obtener una zona aleatoria y se la asigna
    for i, zona in enumerate(empleado["ZONA"]):
        if pd.isna(zona) or zona == "":  
            zone_ran = sel_zone()  
            empleado.loc[i, "ZONA"] = zone_ran 
            
    return empleado

def read_quest(driver):
    try:
        quest = int(driver.find_element("xpath", '/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[1]/div[1]/span').text)
    except:
        quest = int(driver.find_element("xpath", '/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[1]/div[1]').text)
        
    return quest

def create_responses_csv_file():
    date = datetime.now()
    print(date)


def sel_zone():
    #Para los empleados que no tengan zona asignada
    zonas = ["ZOOPLUS", "NIKE", "ELECTROLUX", "EMPTY SPACE"]
    count = len(zonas)
    
    ran = random.randint(0, count-1)
    return zonas[ran]

def rand_6():
    ran = random.randint(1,3)
    return ran

def rand_7():
    ran = random.randint(1,4)
    return ran

def rand_8():
    ran = random.randint(1,5)
    return ran

def rand_9():
    ran = random.randint(1,6)
    return ran

def rand_10():
    ran = random.randint(1,13)
    return ran

def rand_11():
    ran = random.randint(1,6)
    return ran

def rand_12():
    ran = random.randint(1,4)
    return ran

def sel_options_quest(driver, quest, zona):
    if int(quest) == 6:
        rand_times = rand_6()
        print("rand times: {}".format(rand_times))
    
        #print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_6()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            if rand_sel == 2 and zona == "NIKE":
                rand_sel = rand_6()
            else:
               wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
               time.sleep(2)
               
    elif int(quest) == 7:
        rand_times = rand_7()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_7()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
            
    elif int(quest) == 8:
        rand_times = rand_8()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_8()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
        
    elif int(quest) == 9:
        rand_times = rand_9()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_9()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
        
    elif int(quest) == 10:
        rand_times = rand_10()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_10()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
        
    elif int(quest) == 11:
        rand_times = rand_11()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_11()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
    
    elif int(quest) == 12:
        rand_times = rand_12()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_12()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f'/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[2]/div/div/div[{rand_sel}]/div[2]/div[1]/div[2]/label/span/input'))).click()
            time.sleep(2)
            
    wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]"))).click()
    
def random_quest():
    ran = random.randint(6,12)
    return ran

def create_file(list_element, user):
    date = datetime.now()
    name_file = "file"+str(user)+"_"+str(date)+".csv"
    headers = "APC2,NOMBRE,APELLIDOS,PUESTO,ZONA,BLOQUE,RESPUESTAS\n"
    
    with open(name_file, mode='w') as file:
        
        file.write(headers)

        for line in list_element:
            file.write(line+"\n")

# %% [markdown]
# # ***CONFIGURAR PAGINA Y NAVEGADOR***

# %%
# ****** URL DE PRODUCCION ******
url = "https://forms.office.com/Pages/ResponsePage.aspx?id=_j4D8C7YX0ynEjo5SLtFPmrEbLId1F9EvpQx4N_peklUNUc5WFE3Ulo4Qk05REZLT01XRDJIS0lFNC4u"
 
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver_options = Options()
driver_options.add_argument(headers)
driver_options.add_argument('--no-sandbox')

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
#driver.execute_script("window.scrollTo(500, 1080);")

time.sleep(3)

# %% [markdown]
# # ***ENTRAR A LA PRIMERA PAGINA E INTRODUCIR DATOS***

# %%
wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div/div/div[1]/div/div[1]/div/div[2]/div/div[3]/div[3]/button/div"))).click()
time.sleep(2)

# %%
#51509,SANDRA PATRICIA,FERNANDES RIBEIRO,JEFE DE EQUIPO,NIKE
#46000,DANIEL,GARCIA RIVERO,JEFE DE EQUIPO,NIKE
#28199,FATIMA,QUINTERO CORBACHO,JEFE DE EQUIPO,ELECTROLUX
#28232,JOSE,PLATA RODRIGUEZ,JEFE DE EQUIPO,ELECTROLUX
#46586,ISRAEL,GOMEZ CASTROVIEJO,KEY USER,
#49857,ADRIAN,GREGORIO RUIZ,JEFE DE EQUIPO,ZOOPLUS

empleado = leer_csv_apc2()
can = len(empleado)

vuelta = 0

for i in range(6):
    vuelta += 1
    for indice, fila in empleado.iterrows():
        #recorremos el diccionario, uno por uno, rellenando campos
        apc2 = fila["APC2"]
        nombre = fila["NOMBRE"]
        apellidos = fila["APELLIDOS"]
        puesto = fila["PUESTO"]
        zona = fila["ZONA"]
                
        user = f"{indice}/{can} APC2: {apc2}, NOMBRE: {nombre}, APELLIDOS: {apellidos}, PUESTO: {puesto}, ZONA: {zona}"
        print("*"*20)
        print("Vuelta: {}".format(vuelta))
        print("*"*20)
        print(user)
        try: 
            wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[3]/div[5]/span"))).click()
        except:
            pass
        
        
        user_apc2 = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div[2]/div/span/input").send_keys(apc2)
        user_name = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[3]/div[2]/div/span/input").send_keys(nombre)
        user_surname = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[4]/div[2]/div/span/input").send_keys(apellidos)
        user_sel = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[5]/div[2]/div/div[2]/label/span/input").click()
        user_job = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[5]/div[2]/div/div[2]/label/div/span/input").send_keys(puesto)
        user_zone = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[6]/div[2]/div/span/input").send_keys(zona)

        wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, f"/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[3]/div[1]/button"))).click()

        time.sleep(2)
        zone_random = random_quest()


        for i in range (6,14):  # El bucle continuará mientras la zona aleatoria no coincida con la quest
            try:
                quest = read_quest(driver)
            except:
                pass
            print("Zona: {}".format(zone_random))
            print("Bucle quest: {}".format(quest))
            
            # Compara la zona aleatoria con la quest
            if zone_random-1 == quest-1:
                try:
                    print("entramos en funcion")
                    sel_options_quest(driver, quest, zona)
                except:
                    pass
             
            try: 
                wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]"))).click()
                time.sleep(3)
            except Exception as e:
                print(f"error: {e}")
                wait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[3]/div[5]/span"))).click()
                
                print("/"*30)
                time.sleep(5)
               
print("[+] TRABAJO FINALIZADO")
driver.close() 
print("[+] CLOSE CONNECTION")
# Out:
# ********************
# Vuelta: 1
# ********************
# 0/18 APC2: 45987, NOMBRE: NURIA, APELLIDOS: CASTILLO CATALINA, PUESTO: JEFE DE EQUIPO, ZONA: NIKE
# Zona: 10
# Bucle quest: 6
# Zona: 10
# Bucle quest: 7
# Zona: 10
# Bucle quest: 8
# Zona: 10
# Bucle quest: 9
# Zona: 10
# Bucle quest: 10
# entramos en funcion
# rand times: 7
# rand sel: 1
# Zona: 10
# Bucle quest: 11
# Zona: 10
# Bucle quest: 12
# Zona: 10
# Bucle quest: 13
# ********************
# Vuelta: 1
# ********************
# 1/18 APC2: 51003, NOMBRE: GEORGETA CARMEN, APELLIDOS: DUMITRESCU, PUESTO: JEFE DE EQUIPO, ZONA: ZOOPLUS
# Zona: 12
# Bucle quest: 6
# Zona: 12
# Bucle quest: 7
# Zona: 12
# Bucle quest: 8
# Zona: 12
# Bucle quest: 9
# Zona: 12
# Bucle quest: 10
# Zona: 12
# Bucle quest: 11
# Zona: 12
# Bucle quest: 12
# entramos en funcion
# rand times: 1
# rand sel: 2
# Zona: 12
# Bucle quest: 13
# ********************
# Vuelta: 1
# ********************
# ...
