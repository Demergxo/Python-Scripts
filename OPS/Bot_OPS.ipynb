# %% [markdown]
# # ***IMPORTAR LIBRERIAS***

# %%
#from datetime import datetime
import time
from datetime import datetime

from selenium.webdriver import Chrome
from selenium import webdriver
#from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
#from selenium.webdriver.common.by import By
#from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait as wait

import random
#import re
import pandas as pd

# %% [markdown]
# # ***FUNCIONES***

# %%
def leer_csv_apc2():
    #lee el csv y devulve un diccionario con todos los valores
    
    empleado = pd.read_csv('empleados.csv', dtype='string')#na_filter=False) 
    empleado.to_dict('records')  
    
    #si ZONA esta vacio, llama la funcion para obtener una zona aleatoria y se la asigna
    for i, zona in enumerate(empleado["ZONA"]):
        if pd.isna(zona) or zona == "":  
            zone_ran = sel_zone()  
            empleado.loc[i, "ZONA"] = zone_ran 
            
    return empleado

def read_quest(driver):
    try:
        quest = int(driver.find_element("xpath", '/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[1]/div[1]/span').text)
    except:
        quest = int(driver.find_element("xpath", '/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[2]/div[1]/div[1]').text)
        
    return quest

def create_responses_csv_file():
    date = datetime.now()
    print(date)


def sel_zone():
    #Para los empleados que no tengan zona asignada
    zonas = ["ZOOPLUS", "NIKE", "ELECTROLUX", "EMPTY SPACE"]
    count = len(zonas)
    
    ran = random.randint(0, count-1)
    return zonas[ran]

def rand_6():
    ran = random.randint(1,3)
    return ran

def rand_7():
    ran = random.randint(1,4)
    return ran

def rand_8():
    ran = random.randint(1,5)
    return ran

def rand_9():
    ran = random.randint(1,6)
    return ran

def rand_10():
    ran = random.randint(1,13)
    return ran

def rand_11():
    ran = random.randint(1,6)
    return ran

def rand_12():
    ran = random.randint(1,4)
    return ran

def sel_options_quest(driver, quest, zona):
    if int(quest) == 6:
        rand_times = rand_6()
        print("rand times: {}".format(rand_times))
    
        #print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_6()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            if rand_sel == 2 and zona == "NIKE":
                rand_sel = rand_6()
            else:
               driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
               time.sleep(2)
               
               
    elif int(quest) == 7:
        rand_times = rand_7()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_7()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            
            time.sleep(2)
            
            
    elif int(quest) == 8:
        rand_times = rand_8()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_8()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            time.sleep(2)
            
        
    elif int(quest) == 9:
        rand_times = rand_9()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_9()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            time.sleep(2)
            
        
    elif int(quest) == 10:
        rand_times = rand_10()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_10()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            time.sleep(2)
            
        
    elif int(quest) == 11:
        rand_times = rand_11()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_11()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            time.sleep(2)
            
    
    elif int(quest) == 12:
        rand_times = rand_12()
        print("rand times: {}".format(rand_times))
        for i in range(1, rand_times+1):
            #print("for : {}".format(i))
            rand_sel = rand_12()
            print("rand sel: {}".format(rand_sel))
            #print("rand_sel: {}".format(rand_sel))
            driver.find_element("xpath", '//*[@id="question-list"]/div[2]/div[2]/div/table/tbody/tr[{}]/td[2]/div/label/span/input'.format(rand_sel)).click()
            time.sleep(2)
            
    driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]").click()
    
def random_quest():
    ran = random.randint(6,12)
    return ran

def create_file(list_element, user):
    date = datetime.now()
    name_file = "file"+str(user)+"_"+str(date)+".csv"
    headers = "APC2,NOMBRE,APELLIDOS,PUESTO,ZONA,BLOQUE,RESPUESTAS\n"
    
    with open(name_file, mode='w') as file:
        
        file.write(headers)

        for line in list_element:
            file.write(line+"\n")

# %% [markdown]
# # ***CONFIGURAR PAGINA Y NAVEGADOR***

# %%
# ****** URL DE PRODUCCION ******
url = "https://forms.office.com/Pages/ResponsePage.aspx?id=_j4D8C7YX0ynEjo5SLtFPmrEbLId1F9EvpQx4N_peklUNUc5WFE3Ulo4Qk05REZLT01XRDJIS0lFNC4u"
 
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver_options = Options()
driver_options.add_argument(headers)
driver_options.add_argument('--no-sandbox')

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
#driver.execute_script("window.scrollTo(500, 1080);")

time.sleep(3)

# %% [markdown]
# # ***ENTRAR A LA PRIMERA PAGINA E INTRODUCIR DATOS***

# %%
driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[2]/div/div[3]/div[3]/button/div").click()
time.sleep(2)

# %%
#36731,SARA,RUBIO ALONSO,SUPERVISORA,ZOOPLUS
#58100,JOSE ANGEL,SAINZ CRESPO,SITE MANAGER,

empleado = leer_csv_apc2()
can = len(empleado)

for i in range(5):
    for indice, fila in empleado.iterrows():
        #recorremos el diccionario, uno por uno, rellenando campos
        apc2 = fila["APC2"]
        nombre = fila["NOMBRE"]
        apellidos = fila["APELLIDOS"]
        puesto = fila["PUESTO"]
        zona = fila["ZONA"]
                
        user = "{}/{} APC2: {}, NOMBRE: {}, APELLIDOS: {}, PUESTO: {}, ZONA: {}".format(indice, can, apc2, nombre, apellidos, puesto, zona)
        print("*"*20)
        print("Vuelta: {}".format(i))
        print("*"*20)
        print(user)
        
        user_apc2 = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div[2]/div/span/input").send_keys(apc2)
        user_name = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[3]/div[2]/div/span/input").send_keys(nombre)
        user_surname = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[4]/div[2]/div/span/input").send_keys(apellidos)
        user_sel = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[5]/div[2]/div/div[2]/label/span/input").click()
        user_job = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[5]/div[2]/div/div[2]/label/div/span/input").send_keys(puesto)
        user_zone = driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[6]/div[2]/div/span/input").send_keys(zona)

        driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[3]/div[1]/button").click()

        time.sleep(2)
        zone_random = random_quest()


        for i in range (6,14):  # El bucle continuará mientras la zona aleatoria no coincida con la quest
            try:
                quest = read_quest(driver)
            except:
                pass
            print("Zona: {}".format(zone_random))
            print("Bucle quest: {}".format(quest))
            
            # Compara la zona aleatoria con la quest
            if zone_random-1 == quest-1:
                try:
                    print("entramos en funcion")
                    sel_options_quest(driver, quest, zona)
                except:
                    pass
                
            
                
            
            try: 
                driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]").click()
                time.sleep(3)
            except:
                driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[3]/div[5]/span").click()
                print("/"*30)
                time.sleep(5)
               
print("[+] TRABAJO FINALIZADO")
driver.close() 
print("[+] CLOSE CONNECTION")
# Out:
# ********************
# Vuelta: 0
# ********************
# 0/24 APC2: 28228, NOMBRE: JAVIER, APELLIDOS: ALBO CARDO, PUESTO: JEFE DE EQUIPO, ZONA: ZOOPLUS
# Zona: 9
# Bucle quest: 6
# Zona: 9
# Bucle quest: 7
# Zona: 9
# Bucle quest: 8
# Zona: 9
# Bucle quest: 9
# entramos en funcion
# rand times: 5
# rand sel: 2
# rand sel: 6
# rand sel: 5
# rand sel: 3
# rand sel: 3
# Zona: 9
# Bucle quest: 11
# Zona: 9
# Bucle quest: 12
# Zona: 9
# Bucle quest: 13
# Zona: 9
# Bucle quest: 13
# //////////////////////////////
# ********************
# Vuelta: 13
# ********************
# 1/24 APC2: 36733, NOMBRE: RAFAEL, APELLIDOS: ARREDONDO GARCIA, PUESTO: SUPERVISOR, ZONA: ZOOPLUS
# Zona: 10
# Bucle quest: 6
# Zona: 10
# Bucle quest: 7
# Zona: 10
# Bucle quest: 8
# Zona: 10
# Bucle quest: 9
# Zona: 10
# Bucle quest: 10
# entramos en funcion
# rand times: 2
# rand sel: 12
# rand sel: 12
# Zona: 10
# Bucle quest: 12
# Zona: 10
# Bucle quest: 13
# Zona: 10
# Bucle quest: 13
# //////////////////////////////
# ********************
# Vuelta: 13
# ********************
# 2/24 APC2: 45973, NOMBRE: M VAL, APELLIDOS: BARCHINO PLATA, PUESTO: JEFE DE EQUIPO, ZONA: NIKE
# Zona: 11
# Bucle quest: 6
# Zona: 11
# Bucle quest: 7
# Zona: 11
# Bucle quest: 8
# Zona: 11
# Bucle quest: 9
# Zona: 11
# Bucle quest: 10
# Zona: 11
# Bucle quest: 11
# entramos en funcion
# rand times: 3
# rand sel: 3
# rand sel: 6
# rand sel: 3
# Zona: 11
# Bucle quest: 13
# Zona: 11
# Bucle quest: 13
# //////////////////////////////
# ********************
# Vuelta: 13
# ********************
# 3/24 APC2: 59619, NOMBRE: LETICIA, APELLIDOS: CALVO DE FRUTOS, PUESTO: OPS MANAGER, ZONA: ZOOPLUS
# Zona: 12
# Bucle quest: 6
# Zona: 12
# Bucle quest: 7
# Zona: 12
# Bucle quest: 8
# Zona: 12
# Bucle quest: 9
# Zona: 12
# Bucle quest: 10
# Zona: 12
# Bucle quest: 11
# Zona: 12
# Bucle quest: 12
# entramos en funcion
# rand times: 2
# rand sel: 3
# rand sel: 1
# Zona: 12
# Bucle quest: 12
# entramos en funcion
# rand times: 4
# rand sel: 1
# //////////////////////////////
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 55
#      54 try:
# ---> 55     driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]").click()
#      56     time.sleep(3)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[2]/div[1]/button[2]"}
#   (Session info: chrome=122.0.6261.112); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF60B8AAD32+56930]
# 	(No symbol) [0x00007FF60B81F632]
# 	(No symbol) [0x00007FF60B6D42E5]
# 	(No symbol) [0x00007FF60B7198ED]
# 	(No symbol) [0x00007FF60B719A2C]
# 	(No symbol) [0x00007FF60B75A967]
# 	(No symbol) [0x00007FF60B73BCDF]
# 	(No symbol) [0x00007FF60B7581E2]
# 	(No symbol) [0x00007FF60B73BA43]
# 	(No symbol) [0x00007FF60B70D438]
# 	(No symbol) [0x00007FF60B70E4D1]
# 	GetHandleVerifier [0x00007FF60BC26ABD+3709933]
# 	GetHandleVerifier [0x00007FF60BC7FFFD+4075821]
# 	GetHandleVerifier [0x00007FF60BC7818F+4043455]
# 	GetHandleVerifier [0x00007FF60B949766+706710]
# 	(No symbol) [0x00007FF60B82B90F]
# 	(No symbol) [0x00007FF60B826AF4]
# 	(No symbol) [0x00007FF60B826C4C]
# 	(No symbol) [0x00007FF60B816904]
# 	BaseThreadInitThunk [0x00007FFCC8BF7344+20]
# 	RtlUserThreadStart [0x00007FFCC8DC26B1+33]
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 60
#      58                 driver.find_element("xpath", "/html/body/div/div/div[1]/div/div[1]/div/div[3]/div/div[2]/div[1]/div[3]/div[5]/span").click()
#      59                 print("/"*30)
# ---> 60                 time.sleep(5)
#      62 print("[+] TRABAJO FINALIZADO")
#      63 driver.close()
#
# KeyboardInterrupt:
