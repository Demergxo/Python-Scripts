# %% [markdown]
# ## Imports

# %%
#anaconda prompt > conda install -c anaconda openpyxl

import openpyxl

from bs4 import BeautifulSoup
import requests
import time
import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Funcion para extraccion de datos Amazon

# %%
# Conectar y obtener datos desde Amazon

#Se obtiene el User Agent desde http://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

#Funcion para obtener el precio de un producto
def get_amazon_price(URL):

    #Se obtiene el HTML del producto
    page = requests.get(URL, headers=headers, verify=False)
    soup1 = BeautifulSoup(page.content, "html.parser")

    #Se extrae el precio del HTML
    try:
        price = soup1.find("span", { "class" : "a-price" }).find("span", recursive=False).text.strip()
    except AttributeError:
        price = "No se ha podido obtener el precio para este producto."
        time.sleep(1)
        
    return price

# %% [markdown]
# ## Configuracion del Excel

# %%
#Incluir la localizacion del fichero excel con los datos de Amazon:
path = r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx"

# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column
  
print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)

#Introducir el numero de columna en la que se encuentra el ASIN (A=1, B=2, C=3...)
asin_col = 1

#Introducir el numero de la fila en la que se encuentra el primer valor de ASIN
first_asin_row = 2

# se comprueba mostrando por pantalla que la columna de ASIN se esta obteniendo correctamente 
# print("\nValores de ASIN a obtener:")
# for i in range(first_asin_row, row_limit + 1): 
#     cell_obj = sheet_obj.cell(row = i, column = asin_col) 
#     print(cell_obj.value)
# Out:
# Total de filas: 500
# Total de columnas: 5

# %%
# Cerrar el fichero Excel antes de ejecutar esta celda

#Introducir el formato de la web que se va a buscar
web_prefix = "https://www.amazon.es/dp/"

#Introducir el numero de columna en la que se encuentra el precio
precio_col = 3

for i in range(first_asin_row, row_limit + 1): 
    cell_obj = sheet_obj.cell(row = i, column = asin_col)
    ASIN = cell_obj.value
    URL = web_prefix+ASIN
    price = get_amazon_price(URL)
    print(ASIN + " tiene un precio de: " + price)
    
    #Se introduce el precio en el Excel
    c1 = sheet_obj.cell(row = i, column = precio_col)
    c1.value = price
    
#Se guarda el fichero Excel con los cambios aplicados
wb_obj.save(r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx")
# Out:
# B00EDWURZY tiene un precio de: No se ha podido obtener el precio para este producto.
# B00EEAO8M8 tiene un precio de: 15,34€
# B00EE2GTDC tiene un precio de: 9,35€
# B00EF05KVK tiene un precio de: 50,00€
# B00EF2TPSM tiene un precio de: 69,99€
# B00EIGJ2L0 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00EJFE8MS tiene un precio de: 253,90€
# B00EJ3GRMO tiene un precio de: No se ha podido obtener el precio para este producto.
# B00ELIPWUU tiene un precio de: No se ha podido obtener el precio para este producto.
# B00ELUW986 tiene un precio de: 528,01€
# B00ENFISY8 tiene un precio de: 6,92€
# B00ENFI528 tiene un precio de: 5,17€
# B00ENMFOSY tiene un precio de: 46,99€
# B00EOJPTAO tiene un precio de: No se ha podido obtener el precio para este producto.
# B00EON1NP0 tiene un precio de: 257,71€
# B00EOT3QRC tiene un precio de: 13,44€
# B00EO07JRO tiene un precio de: No se ha podido obtener el precio para este producto.
# B00EO3FVQW tiene un precio de: 8,24€
# B00EO3GF2G tiene un precio de: 10,18€
# B00EO3GGKM tiene un precio de: 16,11€
# B00EO3GHU6 tiene un precio de: 13,47€
# B00EO3GN4G tiene un precio de: 7,45€
# B00EO3GSWI tiene un precio de: 16,10€
# B00EO3GW0Q tiene un precio de: 10,18€
# B00EO3GYWM tiene un precio de: 16,03€
# B00EO3G742 tiene un precio de: 12,45€
# B00EO3H0DY tiene un precio de: 10,78€
# B00EO3H3R2 tiene un precio de: 10,31€
# B00EO87WFK tiene un precio de: 139,90€
# B00EPE0EOO tiene un precio de: 49,78€
# B00EPE5U52 tiene un precio de: 35,54€
# B00EPL615S tiene un precio de: 449,99€
# B00EPW4M0S tiene un precio de: No se ha podido obtener el precio para este producto.
# B00EP04U8E tiene un precio de: 29,19€
# B00EQ4N0LC tiene un precio de: 36,19€
# B00ERPZCPC tiene un precio de: 274,73€
# B00ER05LRG tiene un precio de: 3,21€
# B00ESZ3ZN2 tiene un precio de: 14,10€
# B00ES3Z5BO tiene un precio de: 19,74€
# B00EVQL7AG tiene un precio de: 9,29€
# B00EVRE4W8 tiene un precio de: 9,49€
# B00EVRE6X0 tiene un precio de: 62,25€
# B00EVR5KHG tiene un precio de: 20,49€
# B00EVR5KN0 tiene un precio de: 17,99€
# B00EVR5KO4 tiene un precio de: €5,99
# B00EVR5WWO tiene un precio de: 39,99€
# B00EV5AT6A tiene un precio de: 116,36€
# B00EXUGO62 tiene un precio de: 27,92€
# B00EXUKXNW tiene un precio de: 58,69€
# B00EXUOHKC tiene un precio de: 780,25€
# B00EXUQXGI tiene un precio de: 1.405,33 €
# B00EXUTSZ6 tiene un precio de: 72,12€
# B00EXUTT4Q tiene un precio de: 71,17€
# B00EXUWUM4 tiene un precio de: 12,36€
# B00EXUXSKM tiene un precio de: 43,88€
# B00EXUYHG6 tiene un precio de: 14,38€
# B00EXU2PWY tiene un precio de: 362,32€
# B00EXU3ROY tiene un precio de: 703,26€
# B00EXU5YEA tiene un precio de: 107,81€
# B00EXU5YI6 tiene un precio de: 52,28€
# B00EXU6IFO tiene un precio de: 67,49€
# B00EXU6U6Q tiene un precio de: 49,93€
# B00EXU6XWM tiene un precio de: 28,22€
# B00EXU9IC4 tiene un precio de: 26,06€
# B00EXV0MT6 tiene un precio de: 2.498,91€
# B00EXV1CZY tiene un precio de: 11,20€
# B00EXV4OC2 tiene un precio de: 695,14€
# B00EXV463E tiene un precio de: 249,99€
# B00EXV9CK6 tiene un precio de: 26,94€
# B00EYAB2UE tiene un precio de: 4,97€
# B00EYZXJ4Q tiene un precio de: 14,01€
# B00EZJ30A4 tiene un precio de: 59,76 €
# B00EZJ87XO tiene un precio de: 44,71€
# B00EZML6HU tiene un precio de: 39,12€
# B00EZMVOX6 tiene un precio de: 17,90€
# B00EZSUVHU tiene un precio de: €1042,56
# B00E0LGON2 tiene un precio de: 54,34€
# B00E1AOXSK tiene un precio de: No se ha podido obtener el precio para este producto.
# B00E1EQAH8 tiene un precio de: 27,86€
# B00E2PI1XM tiene un precio de: No se ha podido obtener el precio para este producto.
# B00E20KOAA tiene un precio de: 59,99€
# B00E20KOBY tiene un precio de: 54,20€
# B00E20KQ7G tiene un precio de: 84,99€
# B00E3DFQVS tiene un precio de: 249,85€
# B00E3OMHMS tiene un precio de: No se ha podido obtener el precio para este producto.
# B00E3RKC36 tiene un precio de: 89,99€
# B00E3SX6IS tiene un precio de: 44,99€
# B00E40LNKS tiene un precio de: 124,85€
# B00E6097ZY tiene un precio de: 170,23€
# B00E7IIDH8 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00E7N4ELM tiene un precio de: 459,38€
# B00E7OM364 tiene un precio de: 12,63€
# B00E7YUT24 tiene un precio de: 31,90€
# B00E8CZNB2 tiene un precio de: 104,99€
# B00E8HGS0W tiene un precio de: 24,99€
# B00E8HU3LM tiene un precio de: 69,90€
# B00E8KKP3U tiene un precio de: 14,83€
# B00E8KMER0 tiene un precio de: 45,30€
# B00E8KTN4M tiene un precio de: 16,83€
# B00E8KTO1E tiene un precio de: 55,13€
# B00E89Q5OY tiene un precio de: 61,49€
# B00E9AGJ2A tiene un precio de: 17,60€
# B00E9BIKIK tiene un precio de: 29,57€
# B00E9MC9QI tiene un precio de: 89,80€
# B00E9SW4YO tiene un precio de: 22,69€
# B00E9SZHL6 tiene un precio de: 26,14€
# B00E9YGO2Q tiene un precio de: 82,28€
# B00E9YGX5O tiene un precio de: 55,55€
# B00E92EZ9C tiene un precio de: 33,72€
# B00FAHZK7Q tiene un precio de: 24,40€
# B00FAJOBX8 tiene un precio de: 133,65€
# B00FAJ9BTM tiene un precio de: €25,60
# B00FAN638U tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FAO6OKG tiene un precio de: 225,08€
# B00FAO6QEA tiene un precio de: 130,64€
# B00FAO6VDQ tiene un precio de: 117,89€
# B00FBEGMRA tiene un precio de: 69,90€
# B00FBWG128 tiene un precio de: 6,03€
# B00FB29LPM tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FCDAFUU tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FCQO5QW tiene un precio de: 7,98€
# B00FCT255C tiene un precio de: 143,78€
# B00FC2UVRS tiene un precio de: 78,57€
# B00FC46K3A tiene un precio de: 48,43€
# B00FC61K5G tiene un precio de: 24,43€
# B00FDQ34PY tiene un precio de: 31,13€
# B00FEDNE4C tiene un precio de: €2,53
# B00FEGDBTM tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FE8KJ9U tiene un precio de: €18,41
# B00FFECNSI tiene un precio de: 74,01€
# B00FF3X4SC tiene un precio de: 28,99€
# B00FGQUCTW tiene un precio de: 78,29€
# B00FGQUC10 tiene un precio de: 90,58€
# B00FGTDSJ0 tiene un precio de: 31,88€
# B00FGT9WTK tiene un precio de: 552,15€
# B00FG2F0EI tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FH1W7N0 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FJKTRGY tiene un precio de: 88,31€
# B00FJUPMMM tiene un precio de: 26,42€
# B00FJYJYEU tiene un precio de: 4,79€
# B00FJYLR5O tiene un precio de: 60,76€
# B00FJYN8CE tiene un precio de: 62,83€
# B00FJ36E30 tiene un precio de: 189,71€
# B00FKRVRVO tiene un precio de: 15,43€
# B00FKS1YF2 tiene un precio de: 89,20€
# B00FKVA4G4 tiene un precio de: 239,90€
# B00FKWKTRW tiene un precio de: 70,17€
# B00FKW9I7Y tiene un precio de: 104,00€
# B00FKW9KM2 tiene un precio de: 40,00€
# B00FKW9ME8 tiene un precio de: 42,00€
# B00FKW9MT8 tiene un precio de: 93,00€
# B00FKW9M9I tiene un precio de: 123,92€
# B00FKW9Q3K tiene un precio de: 89,40€
# B00FKW9U2M tiene un precio de: 55,00€
# B00FK8T2BA tiene un precio de: 95,89€
# B00FLT6B2G tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FLXSP44 tiene un precio de: 53,79€
# B00FL7JIV4 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FMVLA1A tiene un precio de: 139,15€
# B00FMZMLKK tiene un precio de: €60,45
# B00FNCBTKA tiene un precio de: 53,42€
# B00FNJ7FSI tiene un precio de: 53,62€
# B00FNR4UMO tiene un precio de: 13,44€
# B00FOI7O7U tiene un precio de: 174,99€
# B00FONTSYC tiene un precio de: 174,58€
# B00FON5HTW tiene un precio de: 34,99€
# B00FON5J7C tiene un precio de: 31,38€
# B00FON5KQM tiene un precio de: 50,79€
# B00FO1HV1Q tiene un precio de: 3,62€
# B00FO2OYS8 tiene un precio de: 81,64€
# B00FPDR8BG tiene un precio de: 385,75€
# B00FQD5FSS tiene un precio de: 24,90€
# B00FQD6AHI tiene un precio de: 34,95€
# B00FQD6IWA tiene un precio de: 19,15€
# B00FQIC3AQ tiene un precio de: 149,95€
# B00FQ8UND0 tiene un precio de: 36,88€
# B00FRAYJAK tiene un precio de: 79,35€
# B00FSAZW14 tiene un precio de: 19,66€
# B00FSBBKE6 tiene un precio de: 118,93€
# B00FSB8OLI tiene un precio de: 22,90€
# B00FS2585W tiene un precio de: 109,99€
# B00FUKBHOS tiene un precio de: 174,99€
# B00FU2J2VQ tiene un precio de: 144,79€
# B00FWMGLD6 tiene un precio de: 61,75€
# B00FWM4NJU tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FWRIWRY tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FWRP6UA tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FW3C04O tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FYJ3X92 tiene un precio de: 19,99€
# B00FYM6I2S tiene un precio de: 136,75€
# B00FYQ7P7G tiene un precio de: 108,34€
# B00FYU3RP6 tiene un precio de: 299,00€
# B00FZIOYZO tiene un precio de: 21,47€
# B00FZJIQIO tiene un precio de: 21,88€
# B00FZLVLIY tiene un precio de: No se ha podido obtener el precio para este producto.
# B00FZM2CXQ tiene un precio de: 62,78€
# B00FZWPLTS tiene un precio de: 23,71€
# B00FZ1NO0M tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F0FA122 tiene un precio de: 24,98€
# B00F0FA33E tiene un precio de: 21,98€
# B00F0JPUFQ tiene un precio de: 179,00€
# B00F0LELSG tiene un precio de: 46,13€
# B00F0Q1IH8 tiene un precio de: 28,09€
# B00F2GYKG2 tiene un precio de: 85,73€
# B00F2HYKQ6 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F2H5SEY tiene un precio de: 32,62€
# B00F2J9LPO tiene un precio de: 36,50€
# B00F2MQDU2 tiene un precio de: 56,89€
# B00F2NGCUM tiene un precio de: 10,79€
# B00F2NGU4A tiene un precio de: 32,59€
# B00F2NH6LG tiene un precio de: 55,97€
# B00F2NLBQM tiene un precio de: 34,70€
# B00F2NLB0S tiene un precio de: 20,68€
# B00F2NLCR0 tiene un precio de: 16,60€
# B00F2NLG6W tiene un precio de: 41,27€
# B00F2NLIT2 tiene un precio de: 35,52€
# B00F2NL1BC tiene un precio de: 45,99€
# B00F2NOMM2 tiene un precio de: 51,40€
# B00F2NOMW2 tiene un precio de: 62,84€
# B00F2NPD6G tiene un precio de: 217,00€
# B00F2NVZLI tiene un precio de: €4,29
# B00F2NWAL2 tiene un precio de: €7,79
# B00F2NW2BU tiene un precio de: 9,10€
# B00F2NW5LW tiene un precio de: 17,61€
# B00F2NW6EI tiene un precio de: 31,28€
# B00F2O3VTG tiene un precio de: 3,36€
# B00F3ACGWM tiene un precio de: 26,97€
# B00F3B9DK4 tiene un precio de: 13,68€
# B00F3D7X4K tiene un precio de: 33,81€
# B00F3W915U tiene un precio de: 40,16€
# B00F33MDPY tiene un precio de: 27,80€
# B00F4NOOVE tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F4RZZ5E tiene un precio de: 22,99€
# B00F4Z3Z12 tiene un precio de: 34,35€
# B00F5VO8J8 tiene un precio de: 24,07€
# B00F5VPYOQ tiene un precio de: 109,00€
# B00F5VXRXQ tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F5YDSYG tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F5YDT18 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F595A10 tiene un precio de: €15,43
# B00F6ZTF0A tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F7J5KE0 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00F8DA8P6 tiene un precio de: 40,32€
# B00F8I87P4 tiene un precio de: 24,91€
# B00F8OPS1Y tiene un precio de: 42,77€
# B00F8OQ95I tiene un precio de: 12,16€
# B00F8ORW7M tiene un precio de: 24,61€
# B00F8OSOM4 tiene un precio de: 18,34€
# B00F8OXMX0 tiene un precio de: 31,03€
# B00F8OXNTS tiene un precio de: 40,81€
# B00F8OXOBK tiene un precio de: 10,71€
# B00F8OX2MQ tiene un precio de: 281,45€
# B00F87YU0Q tiene un precio de: 6,72€
# B00F89WV6E tiene un precio de: 23,93€
# B00F9F048E tiene un precio de: 99,99€
# B00F90BSN4 tiene un precio de: 52,95€
# B00F96I4SK tiene un precio de: €89,95
# B00F96J38A tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GAOFHDU tiene un precio de: 6,60 €
# B00GAOF9MO tiene un precio de: 36,84 €
# B00GARARUK tiene un precio de: 139,00€
# B00GA0C9QW tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GA3AI5S tiene un precio de: 79,95€
# B00GA3B6SQ tiene un precio de: 40,40€
# B00GA33TY0 tiene un precio de: 26,61€
# B00GA392PA tiene un precio de: 109,55€
# B00GBQYAVM tiene un precio de: 68,52€
# B00GBZ40YU tiene un precio de: 29,90€
# B00GCLCBJO tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GC8J9CE tiene un precio de: 209,00€
# B00GDE6JC0 tiene un precio de: 160,00€
# B00GDFQS5C tiene un precio de: €13,79
# B00GDFRNME tiene un precio de: 26,49€
# B00GDFWV4E tiene un precio de: €11,14
# B00GD5BKQ4 tiene un precio de: 44,18€
# B00GD5BOE2 tiene un precio de: 45,00€
# B00GD5ECDM tiene un precio de: 127,49€
# B00GD5EL92 tiene un precio de: 119,30€
# B00GD57BXU tiene un precio de: 9,29€
# B00GD57ERI tiene un precio de: 10,86€
# B00GESPZJI tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GEVWBJC tiene un precio de: 18,45€
# B00GEZ9J5C tiene un precio de: 64,91€
# B00GFQ2MUE tiene un precio de: 14,13€
# B00GGFOYDW tiene un precio de: 248,31€
# B00GGR0UR4 tiene un precio de: 75,16€
# B00GHBMFYU tiene un precio de: 89,76€
# B00GHLFQM8 tiene un precio de: 182,44€
# B00GHMKVMM tiene un precio de: 20,73€
# B00GHU5J94 tiene un precio de: 119,15€
# B00GH52TPQ tiene un precio de: 99,00€
# B00GIHGWSS tiene un precio de: 252,01€
# B00GI0GB72 tiene un precio de: 334,76€
# B00GI3URU6 tiene un precio de: 25,53€
# B00GJELMB2 tiene un precio de: €138,90
# B00GJNLTU2 tiene un precio de: 90,00€
# B00GJV3QMI tiene un precio de: 7,30€
# B00GJ3QANI tiene un precio de: 120,16€
# B00GKAC9YO tiene un precio de: 72,45€
# B00GKWG5H4 tiene un precio de: 116,26€
# B00GLO7SN6 tiene un precio de: 55,99€
# B00GLO7X2W tiene un precio de: 68,32€
# B00GLO7YJE tiene un precio de: 81,19€
# B00GLRQ8IO tiene un precio de: 58,96€
# B00GMDS8JY tiene un precio de: 52,37€
# B00GMMFHR6 tiene un precio de: 17,08€
# B00GMO3I5M tiene un precio de: 63,00€
# B00GMPRIAW tiene un precio de: 27,33€
# B00GNB13OM tiene un precio de: 320,54€
# B00GNEE3TQ tiene un precio de: 199,00€
# B00GN55KH4 tiene un precio de: 32,95€
# B00GN6EYVG tiene un precio de: 127,32€
# B00GN8BF8O tiene un precio de: 129,00€
# B00GN8EY0U tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GN8J0FO tiene un precio de: 32,92€
# B00GN89EQE tiene un precio de: 119,90€
# B00GOTQZ9G tiene un precio de: 20,77€
# B00GO0WLIY tiene un precio de: 46,83€
# B00GTFEDTE tiene un precio de: No se ha podido obtener el precio para este producto.
# B00GX2D394 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00G49ROZK tiene un precio de: No se ha podido obtener el precio para este producto.
# B00G8WCGVK tiene un precio de: No se ha podido obtener el precio para este producto.
# B00G9Z6892 tiene un precio de: 24,55€
# B00HF3J8HG tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HHFATSO tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HN50FIC tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HP22OAA tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HQCS1VU tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HR703P6 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HS40S44 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HVP1UQK tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HYG70YM tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HYH81EY tiene un precio de: No se ha podido obtener el precio para este producto.
# B00HZ1Q768 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H02FMBS tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H13YXM0 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H4SI07Q tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H4ZRFPM tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H489O3A tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H489QJ2 tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H489Q7O tiene un precio de: No se ha podido obtener el precio para este producto.
# B00H7A0OR0 tiene un precio de: No se ha podido obtener el precio para este producto.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1120/3262247420.py in <module>
#      11     ASIN = cell_obj.value
#      12     URL = web_prefix+ASIN
# ---> 13     price = get_amazon_price(URL)
#      14     print(ASIN + " tiene un precio de: " + price)
#      15
#
# ~\AppData\Local\Temp/ipykernel_1120/1595848087.py in get_amazon_price(URL)
#       8
#       9     #Se obtiene el HTML del producto
# ---> 10     page = requests.get(URL, headers=headers, verify=False)
#      11     soup1 = BeautifulSoup(page.content, "html.parser")
#      12
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
