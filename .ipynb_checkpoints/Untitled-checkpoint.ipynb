# %%
from pylibdmtx.pylibdmtx import encode
from pylibdmtx.pylibdmtx import decode
from PIL import Image

directory = os.getcwd()

location_string = "B.00"

for i in range(11):

    iterate_string = location_string + str(i)


    encoded = encode(iterate_string.encode('utf8')(#, scheme="Ascii", size = "80x80")
    img = Image.frombytes('RGB', (encoded.width, encoded.height), encoded.pixels)
    barcode="barcode{}.png".format(i)
    barcode = directory+"\\"+barcode
    img.save(barcode)
    print(decode(Image.open(barcode)))
# Out:
# [Decoded(data=b'B.000', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.001', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.002', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.003', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.004', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.005', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.006', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.007', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.008', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.009', rect=Rect(left=9, top=10, width=400, height=399))]
# [Decoded(data=b'B.0010', rect=Rect(left=9, top=10, width=400, height=399))]
