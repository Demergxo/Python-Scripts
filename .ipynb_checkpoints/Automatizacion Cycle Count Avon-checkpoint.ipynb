# %% [markdown]
# ## Imports

# %%
#anaconda prompt > conda install -c anaconda openpyxl

import openpyxl

from bs4 import BeautifulSoup
import requests
import time
import datetime
import urllib.request, urllib.error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Funcion para extraccion de datos Amazon

# %%
# Conectar y obtener datos desde Amazon

#Se obtiene el User Agent desde http://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

#Funcion para obtener el precio de un producto
def get_amazon_price(URL):

    #Se obtiene el HTML del producto
    page = requests.get(URL, headers=headers, verify=False)
    soup1 = BeautifulSoup(page.content, "html.parser")

    #Se extrae el precio del HTML
    try:
        price = soup1.find("title").text.strip()
    except AttributeError:
        price = "No se ha podido obtener el precio para este producto."
        time.sleep(1)
           
        
    return price

# %% [markdown]
# ## Configuracion del Excel

# %%
#Incluir la localizacion del fichero excel con los datos de Amazon:
path = r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx"

# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column
  
print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)

#Introducir el numero de columna en la que se encuentra el ASIN (A=1, B=2, C=3...)
asin_col = 1

#Introducir el numero de la fila en la que se encuentra el primer valor de ASIN
first_asin_row = 2

# se comprueba mostrando por pantalla que la columna de ASIN se esta obteniendo correctamente 
# print("\nValores de ASIN a obtener:")
# for i in range(first_asin_row, row_limit + 1): 
#     cell_obj = sheet_obj.cell(row = i, column = asin_col) 
#     print(cell_obj.value)
# Out:
# Total de filas: 347
# Total de columnas: 5

# %%
# Cerrar el fichero Excel antes de ejecutar esta celda

#Introducir el formato de la web que se va a buscar
web_prefix = "https://www.amazon.es/dp/"

#Introducir el numero de columna en la que se encuentra el precio
precio_col = 3

for i in range(first_asin_row, row_limit + 1): 
    cell_obj = sheet_obj.cell(row = i, column = asin_col)
    ASIN = cell_obj.value
    URL = web_prefix+ASIN
    price = get_amazon_price(URL)
    print(ASIN + " Descripcion: " + price)
    
    #Se introduce el precio en el Excel
    c1 = sheet_obj.cell(row = i, column = precio_col)
    c1.value = price
    
#Se guarda el fichero Excel con los cambios aplicados
wb_obj.save(r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx")
print("PROCESO FINALIZADO/ARCHIVO GUARDADO")
# Out:
# B07F7W7ZWL Descripcion: Amazon.es
# B07HVKF3T9 Descripcion: Laurastar 156.0045.898 Tabla de planchar para carrito de vapor, aluminio : Amazon.es: Hogar y cocina
# B07KX3CG57 Descripcion: Amazon.es
# B07BB9FQDZ Descripcion: Amazon.es
# B07HB1JDV4 Descripcion: Amazon.es
# B079DT8WHM Descripcion: Amazon.es
# B07KX5YXVZ Descripcion: Amazon.es
# B07NYYTG6B Descripcion: Krups Quattro Force Arabica Latte EA819E - Cafetera superautomática 15 bares, pantalla LCD, programas de leche y personalización bebidas, molinillo metálico profesional, modo limpieza, jarra leche : Amazon.es: Hogar y cocina
# B07KXKQ281 Descripcion: Amazon.es
# B07D752FD1 Descripcion: Amazon.es
# B07P6QHFFW Descripcion: Amazon.es
# B07KYH14FQ Descripcion: EDESA, Microondas Marco Encastre Integrado, Modelo EMW 2020-I-X, Capacidad de 20 litros, 5 Niveles de Potencia, Acabado en Acero Inoxidable : Amazon.es: Hogar y cocina
# B07P7WKDZX Descripcion: Amazon.es
# B07HB63P4W Descripcion: Amazon.es
# B07CPD2H9Z Descripcion: Amazon Basics Sartén de Inducción Antiadherente - 28 cm : Amazon.es: Hogar y cocina
# B07L348XVK Descripcion: Amazon.es
# B0798CQNGM Descripcion: Amazon.es
# B07D94DTNG Descripcion: HENDI Barras de adaptación de recipientes Gastronorm - Kitchen Line - 532x20 mm : Amazon.es: Hogar y cocina
# B07L377K39 Descripcion: Estoralis Vera Estor Enrollable Doble Tejido, Noche Y Día Negro 125 x 175 cm : Amazon.es: Hogar y cocina
# B079ZVBPXG Descripcion: Amazon.es
# B07B7VB224 Descripcion: Amazon.es
# B0083BDHDK Descripcion: Amazon.es
# B0037AFVXQ Descripcion: Amazon.es
# B0083BVTJ4 Descripcion: Vitakraft - Lecho de Cáñamo para Todo Tipo de Roedores, Térmico, Absorbente, Controla Olores - 30 L : Amazon.es: Productos para mascotas
# B006WNCFK2 Descripcion: FEBER Cross Alpha 6 V (Famosa 800007932) : Amazon.es: Juguetes y juegos
# B0083TMZHQ Descripcion: Amazon.es
# B003BWM3QI Descripcion: Amazon.es
# B0086W7T12 Descripcion: Amazon.es
# B007416OFS Descripcion: Haku Möbel 42390 Mesita Auxiliar Blanco, 30 x 30 x 70 cm : Amazon.es: Hogar y cocina
# B004BR37K8 Descripcion: Amazon.es
# B00GULUN8W Descripcion: Element System 10001-00005 Soporte para estantes, Aluminio, 50cm : Amazon.es: Bricolaje y herramientas
# B001NYV36M Descripcion: Amazon.es
# B00H29V2TU Descripcion: Amazon.es
# B004C6N2PI Descripcion: Fiskars Rompehielos, Ancho de pala 17.5 cm, Acero al boro-Pala/Madera-Mango, Negro, 1001639 : Amazon.es: Jardín
# B00H99ZZFA Descripcion: Amazon.es
# B008DI1OPQ Descripcion: Amazon.es
# B007DZSSDG Descripcion: Amazon.es
# B008DVVHHS Descripcion: Amazon.es: Simba 5738565 Steffi Love y su Familia en Formato Tubo, Multicolor: Juguetes y juegos
# B001EIO7TW Descripcion: Amazon.es
# B008EIAEQU Descripcion: Amazon.es
# B000KKJ3YO Descripcion: Amazon.es
# B004CL5Z76 Descripcion: Amazon.es
# B005AFF5KU Descripcion: Amazon.es
# B008F6C662 Descripcion: PARAVIENTOS 3 MÓDULOS PAELLERAS (HASTA 70 CM Ø) VAELLO : Amazon.es: Deportes y aire libre
# B005CF0NNC Descripcion: Caldwell 505-501 Lanza Platos de Mano, Verde, Talla Única : Amazon.es: Deportes y aire libre
# B008F6C6A8 Descripcion: Amazon.es
# B00CV4DDOS Descripcion: Amazon.es
# B008F6FJ8Y Descripcion: G2 Trading Company 56 - G2 empresa comercial buzón de acero 0 calder - verde : Amazon.es: Bricolaje y herramientas
# B00CW0WPR2 Descripcion: Amazon.es
# B008GKBMH6 Descripcion: Amazon.es
# B00CWZOEJY Descripcion: Amazon.es
# B008GZN134 Descripcion: Amazon.es
# B00CWZRX7E Descripcion: Amazon.es
# B008GZND32 Descripcion: GAH-Alberts - Perfil angular (aluminio) : Amazon.es: Bricolaje y herramientas
# B00CXMCSDK Descripcion: Juego de Alfombras de Moqueta a Medida Premium Negro : Amazon.es: Coche y moto
# B001P82428 Descripcion: Thule Freeway 3, portabicicletas Colgante básico de portón Trasero, diseñado para Dos volúmenes y berlinas (para 3 Bicicletas), référencia 968. : Amazon.es: Coche y moto
# B00D0DMDUY Descripcion: Valeo 850599 : Amazon.es: Coche y moto
# B008GZNG66 Descripcion: Amazon.es
# B000XXO7B2 Descripcion: Amazon.es
# B004EEGTO4 Descripcion: Amazon.es
# B00DF1EMEQ Descripcion: Amazon.es
# B001P8MMY8 Descripcion: Amazon.es
# B002SAFFPK Descripcion: Amazon.es
# B0001DI46I Descripcion: Amazon.es
# B005SO4O3C Descripcion: Amazon.es
# B004GLAA72 Descripcion: Amazon.es
# B002TM3I92 Descripcion: Amazon.es
# B008H195RI Descripcion: GAH-Alberts - Perfil de esquina (acero, con orificios) : Amazon.es: Bricolaje y herramientas
# B000A63M0O Descripcion: Amazon.es
# B008H9UVPU Descripcion: Alpine SWE-815 - Sistema de sonido para coche, color negro : Amazon.es: Electrónica
# B006020KUM Descripcion: Amazon.es
# B008HBU9JQ Descripcion: GAH-Alberts - Tubo cuadrado de acero inoxidable : Amazon.es: Bricolaje y herramientas
# B002X78AXW Descripcion: Amazon.es
# B008HBY4ZQ Descripcion: Amazon.es
# B00615UPE4 Descripcion: Amazon.es
# B004GYB1TU Descripcion: Metabo KGS 216 M (619260000) - Ingletadora telescópica 1.5 Kw, Ø 216 mm, 1500 W disco 216 mm : Amazon.es: Bricolaje y herramientas
# B00E92X23W Descripcion: Green Valley 2 Barras 156915 Easy-One SW Aluminio, 120 cm : Amazon.es: Coche y moto
# B008HRG8FE Descripcion: Bosch 2 608 642 495 - Hoja de sierra circular Expert for Multi Material (300 x 30 x 2,4 mm, 96) : Amazon.es: Bricolaje y herramientas
# B00EE9G7C8 Descripcion: Documento no encontrado
# B001PR18U8 Descripcion: Amazon.es
# B00EP6LXME Descripcion: Amazon.es
# B004HG2N8A Descripcion: Amazon.es
# B00EUAMBJY Descripcion: Hansgrohe 26621000 Raindance Select E 120 set de ducha, 3 tipos de chorro, cromo : Amazon.es: Bricolaje y herramientas
# B004HYC5TE Descripcion: Amazon.es
# B00EXS9WD6 Descripcion: Teka - Grifo Franke 0185134, RETRO ABATIBLE BRONCE : Amazon.es: Bricolaje y herramientas
# B001PUQ8ZU Descripcion: Haku Möbel consola, madera maciza, blanca, 36 x 43 x 76 cm : Amazon.es: Hogar y cocina
# B006B4O5LY Descripcion: Amazon.es
# B0002F7JT8 Descripcion: Amazon.es
# B006DV8I8Q Descripcion: Amazon.es
# B008QVVUPY Descripcion: VANGUARD Quest B62 Bipode, Unisex, Negro : Amazon.es
# B00175RNR0 Descripcion: Amazon.es
# B008X3JIVS Descripcion: Amazon.es
# 032337462X Descripcion: Amazon.es
# B008XCNOQE Descripcion: Amazon.es
# B00F63J14W Descripcion: Metabo ASR 25 L SC - ASPIRADORES UNIVERSALES PARA SECO Y HÚMEDO : Amazon.es: Hogar y cocina
# B004IKTTA0 Descripcion: Amazon.es
# B00FC0TVGC Descripcion: Amazon.es
# B004IU24I4 Descripcion: Amazon.es
# B00FKW95BS Descripcion: Dogar Altea Estanteria, Pino, Miel, 120x40x28 cm : Amazon.es: Hogar y cocina
# B00904SKAY Descripcion: Amazon.es
# B00FND6M9C Descripcion: Amazon.es
# B004JHST08 Descripcion: Noble Collection Expositor varitas Harry Potter 10 varitas (no Incluidas) : Amazon.es: Juguetes y juegos
# B006LMX1WK Descripcion: Amazon.es
# B000SM4G7I Descripcion: Amazon.es
# B00FU3ISRO Descripcion: Amazon.es
# B004KU832S Descripcion: BRIO- Juego primera edad (33513) : Amazon.es: Juguetes y juegos
# B0018LUNJI Descripcion: KidKraft Estantería Expositor de Madera, Muebles de Dormitorio para niños, exhibidor de Libros para Almacenamiento, Multicolor (Colores Primarios) : Amazon.es: Hogar y cocina
# B00006BBDR Descripcion: Amazon.es
# B00FYKP7VI Descripcion: HAUPTSTADTKOFFER - SPREE - Equipaje de mano, Maleta rígida, Trolley expandible, 4 ruedas dobles, TSA : Amazon.es: Equipaje
# B00938XDXQ Descripcion: Amazon.es
# B006ZYY236 Descripcion: Amazon.es
# B0002GY7MO Descripcion: Sobre el escenario Tiltback con función de atril soportes de amplificador para guitarra : Amazon.es: Instrumentos musicales
# B00GD5EIFO Descripcion: Versa Seatle Mesa Auxiliar para el Salón, la Habitación o la Cocina. Moderna Mesilla Baja, Medidas (Al x L x An) 60 x 50 x 50 cm, Madera y Metal, Color Blanco y Negro : Amazon.es: Hogar y cocina
# B0095JFOVM Descripcion: Amazon.es
# B0072J0886 Descripcion: Amazon.es
# B00969PNDA Descripcion: Amazon.es
# B0073AIXOK Descripcion: Amazon.es
# B0096DQVPU Descripcion: Amazon.es
# B00GLO7YJE Descripcion: Amazon.es
# B0096DZ412 Descripcion: Amazon.es
# B001ANTFDY Descripcion: Amazon.es
# B0098UUXGO Descripcion: Amazon.es
# B00GY1G7II Descripcion: Bi-Office Maya - Tablero de anúncios con marco de aluminio, 60 x 45 cm, fieltro verde : Amazon.es: Oficina y papelería
# B004MLTV76 Descripcion: Fellowes Bankers Box 00236 - Caja de archivo definitivo automático, A3, lomo 100 mm, blanco y azul (10 unidades) : Amazon.es: Oficina y papelería
# B00784L2CG Descripcion: Amazon.es
# B004OB75LI Descripcion: Kamino - Flam – Tubo para chimenea y estufa de leña, Tubo vitrificado –  acero resistente a altas temperaturas – Negro, Ø 150 mm/longitud 1000 mm : Amazon.es: Bricolaje y herramientas
# B000ROHR00 Descripcion: Amazon.es
# B000T5EL4M Descripcion: Amazon.es
# B00H8T05D8 Descripcion: Amazon.es
# B004P1IID6 Descripcion: VALEO SILENCIO VM206 escobilla limpiaparabrisas - 574194 - Longitud frontal: 650mm / 550mm - Cantidad set 2 Unidades - (para entrenamiento de vehículos a la izquierda y derecha) : Amazon.es: Coche y moto
# B007C1URAI Descripcion: Amazon.es
# B004P1IIWW Descripcion: VALEO SILENCIO escobilla limpiaparabrisas VF357-574371 - Longitud frontal: 580mm / 450mm - Cantidad set 2 Unidades - (para vehiculos de conduccion izquierda y derecha) : Amazon.es: Coche y moto
# B0000Y8C2Y Descripcion: Celestron Powerseeker 114 EQ - Telescopio reflector : Amazon.es: Electrónica
# B001THQ4ZS Descripcion: Apollo Gardening Ltd GF6588 - Contenedor de Agua: Amazon.es: Jardín
# B00HNX0MXC Descripcion: Amazon.es
# B004P1IJCG Descripcion: Amazon.es
# B007JFMIWC Descripcion: Amazon.es
# B009GZLM0M Descripcion: Amazon.es
# B007NYIMHE Descripcion: Amazon.es
# B004S28P4E Descripcion: Amazon.es
# B000SKJF8U Descripcion: Lacor Cacerola, Acero Inoxidable 18/10, Plata, 45 cm : Amazon.es: Hogar y cocina
# B004S2G5C8 Descripcion: Amazon.es
# B00CIZULYK Descripcion: Amazon.es
# B001TWXZU0 Descripcion: Amazon.es
# B000NBYK0C Descripcion: Amazon.es
# B001U3VC8A Descripcion: Amazon.es
# B00CMQ36QU Descripcion: Amazon.es
# B009JTG4LW Descripcion: Amazon.es
# B00CRD0N6Y Descripcion: Amazon.es
# B004TNOLCW Descripcion: Amazon.es
# B000ND515S Descripcion: Amazon.es
# B009LZ03KM Descripcion: Amazon.es
# B00CV41YVM Descripcion: Amazon.es
# B009LZN1CE Descripcion: Amazon.es
# B000WFFTPY Descripcion: Amazon.es
# B009N9XHDQ Descripcion: Amazon.es
# B00CVZSVVW Descripcion: Amazon.es
# B001ULCOM0 Descripcion: Amazon.es
# B00CW0WSRO Descripcion: Valeo 835074 : Amazon.es: Coche y moto
# B009RM4JAY Descripcion: Amazon.es
# B000ND8XFS Descripcion: TRIXIE Poste Rascador Altea para Gatos : Amazon.es: Productos para mascotas
# B009SJ5BDK Descripcion: HENDI Bandeja de servicio - ø400 mm : Amazon.es: Industria, empresas y ciencia
# B002OB3QRC Descripcion: Pinolino 172330 - Barandilla para camas : Pinolino: Amazon.es: Bebé
# B009UHWQOW Descripcion: CURVER Inodoro para gatos, bandeja sanitaria cerrada, compartimento inferior extraíble para facilitar la limpieza, pala para arena y alfombrilla incluidas, dimensiones: 51 x 39 x 39 cm, Blanco : Amazon.es: Productos para mascotas
# B005LB2OTS Descripcion: Amazon.es
# B009UYYH8I Descripcion: Amazon.es
# B00CXM40YU Descripcion: J. ALFOMBRAS PREMIUM NEGRO MOD. (03-08) : Amazon.es: Coche y moto
# B001UNXBGQ Descripcion: Amazon.es
# B00CXMALL6 Descripcion: Amazon.es
# B004ULLZ9K Descripcion: Amazon.es
# B00CXMD2T4 Descripcion: Amazon.es
# B001US0HEU Descripcion: Amazon.es
# B00D0CC63E Descripcion: Amazon.es
# B004VDQ3E4 Descripcion: Amazon.es
# B005LR6H5O Descripcion: Compra Arcos Serie Riviera, Cuchillo Cocinero, Hoja de Acero Inoxidable Forjado Nitrum 300 mm, Mango de Polyoxymethylene, POM Color Negro en Amazon.es
# B00ABGXFL4 Descripcion: Casselin CPC60 - Percolador de café 60 tazas : Amazon.es: Hogar y cocina
# B00D2PIG2E Descripcion: Amazon.es
# B00ABH01GA Descripcion: Amazon.es
# B005M2V2FI Descripcion: Amazon.es
# B001VXUHRG Descripcion: Amazon.es
# B005MR9MRS Descripcion: Amazon.es
# B00AFBRHFU Descripcion: Bandeja de bambú giratoria : Amazon.es: Hogar y cocina
# B005MXJVN2 Descripcion: Amazon.es
# B004VV5LQM Descripcion: Avery P460 - Cortador de papel (A3), color gris : Amazon.es
# B000NK1UVK Descripcion: Fellowes Pulsar E 300 - Encuadernadora eléctrica de canutillo de plástico, uso frecuente : Amazon.es
# B00AJTLAAG Descripcion: Amazon.es
# B00DNDHRDE Descripcion: Barbacoa eléctrica SUNTEC BBQ-9479 | Uso exterior como barbacoa de sobremesa o con pie | Barbacoa para balcón, terraza, jardín y camping | Cocción eléctrica con máx. 2400 vatios | Tapa dorada : Amazon.es: Bricolaje y herramientas
# B00ANLC3SI Descripcion: Amazon.es
# B0007VHFUA Descripcion: Amazon.es
# B004WCO58K Descripcion: Kärcher Lanza de extensión para riego (2.645-157.0) : Amazon.es: Jardín
# B00DREBXZC Descripcion: Amazon.es
# B000T5ELR4 Descripcion: Amazon.es
# B0000223R5 Descripcion: IRWIN T5212ED - Tornillo de banco para madera - Desbloqueo rápido, 9 pulgadas/230 mm : Amazon.es: Bricolaje y herramientas
# B00ASXUH0W Descripcion: Silla de Oficina Ergonomica, Silla de Escritorio, Modelo Flip, Acabado en Color Negro y Madera, Medidas: 46 cm (Ancho) x 68 cm (Fondo) x 52-62 cm (Alto) : Amazon.es: Hogar y cocina
# B00DS7AVKQ Descripcion: DeWalt DCD790D2-QW - Taladro atornillador (9 W, 14,4 V) : Amazon.es: Bricolaje y herramientas
# B004WNIMWO Descripcion: Amazon.es
# B00DSNI4DQ Descripcion: Amazon.es
# B001W6Q5CI Descripcion: Fiskars Maza 3kg L, Peso total: 3.9 kg, Acero al carbono (forjado), Negro/Naranja, 1001619 : Amazon.es: Bricolaje y herramientas
# B005VOZLEK Descripcion: Amazon.es
# B001W6Q5CS Descripcion: Amazon.es
# B005WS0Z8M Descripcion: Amazon.es
# B00AYR3KV0 Descripcion: Amazon.es
# B00DW3TRLA Descripcion: Bellota 6009-600 - CORTAVARILLAS : Amazon.es: Bricolaje y herramientas
# B00AZWEGGW Descripcion: Amazon.es
# B000A63M0Y Descripcion: Amazon.es
# B0025B0EXK Descripcion: HP Kit de opciones de procesador E5504 ML150 Intel Xeon G6a 2,0 GHz Quad Core de 80 W - Procesador : Amazon.es: Informática
# B00E3X0K14 Descripcion: Amazon.es
# B004Y57CTO Descripcion: Amazon.es
# B0060KB9Z4 Descripcion: Amazon.es
# B00B19T7QC Descripcion: Amazon.es
# B001349SOQ Descripcion: Makita HR 2470 Martillo Ligero, 780 W, 220 V : Amazon.es: Bricolaje y herramientas
# B00B1C1PX2 Descripcion: Facom E.306-30D - Llave dinamométrica con lectura de par 30 Nm : Amazon.es: Bricolaje y herramientas
# B00E8HU3LM Descripcion: Sweetnight satén Topper, Algodón, Blanco, 140x190/200 cm : Amazon.es: Hogar y cocina
# B00B1C1X6G Descripcion: Amazon.es
# B00E9N33TE Descripcion: Dainese Super Speed Tex Jacket Chaqueta Moto Verano : Amazon.es: Coche y moto
# B00B1C2YPK Descripcion: Amazon.es
# B00EDV9R2E Descripcion: Razor A5 Lux Patineta, Niños, Azul, Talla Única : Amazon.es: Deportes y aire libre
# B004YJT8X8 Descripcion: Amazon.es
# B002Y1INMU Descripcion: Koopman International b.vKF340 PLUVIOMETRO PINCHO PLASTICO: Amazon.es: Jardín
# B004YZM7LM Descripcion: Amazon.es
# B000092QYJ Descripcion: Epson Premium Semigloss Photo Paper - Papel fotográfico : Epson: Amazon.es: Oficina y papelería
# B00261LZEG Descripcion: Agujas de tejer de 15 cm. : Amazon.es: Hogar y cocina
# B0013LED3K Descripcion: Amazon.es
# B00B3SV1YM Descripcion: BRA Olla Profesional 30 Tapa INOX, Acero Inoxidable 18/10, Único, 30 cm : Amazon.es: Hogar y cocina
# B000CZ0RK6 Descripcion: Amazon.es
# B00B4DF07U Descripcion: CATA 00665000 Helicoidales | Modelo LHV 400 | Extractor de Alto Rendimiento y bajo Nivel Sonoro | Clase de Eficiencia Energética B, 215 W, 230 V, Acero inoxidable : Amazon.es: Bricolaje y herramientas
# B0015Z4Y1A Descripcion: Amazon.es
# B00B5C6P24 Descripcion: Amazon.es
# B00EXS989O Descripcion: Amazon.es
# B004ZGNGWO Descripcion: Amazon.es
# B0068M6NHI Descripcion: Amazon.es
# B0028HYTR8 Descripcion: Metaltex Jeanette Manguero de Planchar de Sobremesa, Metal, Multicolor, 50x25x20 cm : Amazon.es: Hogar y cocina
# B0030GEV0Q Descripcion: Lafuma Mesa de jardín plegable con altura ajustable, 91x69 cm, Resistente a la intemperie, California, Carbón (Gris), LFM1491-3631 : Amazon.es: Deportes y aire libre
# B0050IC0CI Descripcion: Hauptstadtkoffer Alex, Maleta a Mano Rígida, Gris (Titanio), Set de 3 : Amazon.es: Equipaje
# B000QB6PFW Descripcion: Amazon.es
# B00B9BR9JE Descripcion: SKF VKJC 5755 Kit de transmisión : Amazon.es: Coche y moto
# B006CV14T2 Descripcion: Amazon.es
# B00293LE3S Descripcion: Amazon.es
# B00342V1TU Descripcion: Amazon.es: PINOLINO 269425 - Carretilla para Juguetes: Juguetes y juegos
# B00BBT8EV6 Descripcion: Peugeot EBT 200 - Tornillo de banco (200 mm) : Amazon.es: Bricolaje y herramientas
# B00F2NVQ94 Descripcion: Amazon.es
# B00BBVUU52 Descripcion: Mapco 91917 - Resorte a gas (para zona del maletero) : Amazon.es: Coche y moto
# B00F3A2W8K Descripcion: Amazon.es
# B00BCJVT7Q Descripcion: Amazon.es
# B00F5VPYOQ Descripcion: Laurastar COMFORTBOARD - Accesorio de planchado : Amazon.es: Hogar y cocina
# B0029F24E4 Descripcion: Amazon.es
