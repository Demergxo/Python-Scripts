# %% [markdown]
# ## Imports

# %%
#anaconda prompt > conda install -c anaconda openpyxl

import openpyxl

from bs4 import BeautifulSoup
import requests
import time
import datetime
import urllib.request, urllib.error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Funcion para extraccion de datos Amazon

# %%
# Conectar y obtener datos desde Amazon

#Se obtiene el User Agent desde http://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

#Funcion para obtener el precio de un producto
def get_amazon_price(URL):

    #Se obtiene el HTML del producto
    page = requests.get(URL, headers=headers, verify=False)
    soup1 = BeautifulSoup(page.content, "html.parser")

    #Se extrae el precio del HTML
    try:
        price = soup1.find("title").text.strip()
    except AttributeError:
        price = "No se ha podido obtener el precio para este producto."
        time.sleep(1)
           
        
    return price

# %% [markdown]
# ## Configuracion del Excel

# %%
#Incluir la localizacion del fichero excel con los datos de Amazon:
path = r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx"

# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column
  
print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)

#Introducir el numero de columna en la que se encuentra el ASIN (A=1, B=2, C=3...)
asin_col = 1

#Introducir el numero de la fila en la que se encuentra el primer valor de ASIN
first_asin_row = 2

# se comprueba mostrando por pantalla que la columna de ASIN se esta obteniendo correctamente 
# print("\nValores de ASIN a obtener:")
# for i in range(first_asin_row, row_limit + 1): 
#     cell_obj = sheet_obj.cell(row = i, column = asin_col) 
#     print(cell_obj.value)
# Out:
# Total de filas: 121
# Total de columnas: 5

# %%
# Cerrar el fichero Excel antes de ejecutar esta celda

#Introducir el formato de la web que se va a buscar
web_prefix = "https://www.amazon.es/dp/"

#Introducir el numero de columna en la que se encuentra el precio
precio_col = 3

for i in range(first_asin_row, row_limit + 1): 
    cell_obj = sheet_obj.cell(row = i, column = asin_col)
    ASIN = cell_obj.value
    URL = web_prefix+ASIN
    price = get_amazon_price(URL)
    print(ASIN + " Descripcion: " + price)
    
    #Se introduce el precio en el Excel
    c1 = sheet_obj.cell(row = i, column = precio_col)
    c1.value = price
    
#Se guarda el fichero Excel con los cambios aplicados
wb_obj.save(r"C:\Users\jgmeras\Documents\Python Scripts\Precios.xlsx")
print("PROCESO FINALIZADO/ARCHIVO GUARDADO")
# Out:
# B09T6WGMT3 Descripcion: Cecotec Aspirador Escoba sin Cable Conga Rockstar 880 Ultimate ErgoFlex. 480 W, 3 en 1: Vertical, Escoba y de Mano, Motor Digital, 30 kPa, 100 mins de autonomía, Cepillo Jalisco, Tubo Flexible : Amazon.es: Hogar y cocina
# B07G3ZQTT4 Descripcion: Orbegozo PWM 2147 Ventilador Industrial, 45 cm de diámetro, 3 velocidades de ventilación, Mando a Distancia, Sistema antivuelco, Cabezal oscilante multiorientable, 130 W, Metal : Amazon.es: Hogar y cocina
# B09KZC2W5F Descripcion: ZINUS Colchón de espuma Cooling Essential | Adaptable de 7 zonas | 90 x 190 cm | Altura de 15 cm | Asequible | OEKO-TEX : Amazon.es: Hogar y cocina
# B09KZGFW7K Descripcion: ZINUS Colchón de espuma Cooling Essential | Adaptable de 7 zonas | 135 x 190 cm | Altura de 15 cm | Asequible | OEKO-TEX : Amazon.es: Hogar y cocina
# B09KZM2XPX Descripcion: ZINUS Colchón de espuma Cooling Essential | Adaptable de 7 zonas | 90 x 190 cm | Altura de 20 cm | Asequible | OEKO-TEX : Amazon.es: Hogar y cocina
# B014FHB72I Descripcion: Bestway 56404 - Piscina Desmontable Tubular Infantil Deluxe Splash Frame Pool, Multicolor, 150 x 38 x 75 cm: Amazon.es: Jardín
# B004YJTB1C Descripcion: Ferplast large and spacious rabbits cage CASITA 120, guinea pigs and small animals house. Rounded openable roof, accessories are included, made of varnished White Metal and plastic, 119 x58 x h 60 cm : Amazon.es: Productos para mascotas
# B08BF68S4Q Descripcion: Tumbona plegable de Madera acacia Aktive Garden: Amazon.es: Jardín
# B08CBGYZZ1 Descripcion: Clas OE7201 Tanque de Ultrasonidos, 200W, 40Khz, Multicolor, 9 L : Amazon.es: Industria, empresas y ciencia
# B089NTCMBT Descripcion: Xiaomi Scooter eléctrico Mi, versión francesa con cerradura : Xiaomi: Amazon.es: Hogar y cocina
# B07WRMDX4N Descripcion: SANAT Alfombra Moderna para Sala de Estar, Color Crema, tamaño: 160 x 230 cm : Amazon.es: Hogar y cocina
# B07WSRNY16 Descripcion: Sanat Alfombra de salón, Aqua, Pelo Largo, Moderna, tamaño: 160 x 230 cm : Amazon.es: Hogar y cocina
# B07Z2BGX17 Descripcion: Sanat Alfombra Redonda, Gri,s Pelo Largo, Moderna Alfombra para salón, Dormitorio, Comedor o habitación de los niños, tamaño: 150 x 150 cm. : Amazon.es: Hogar y cocina
# B07Z2B6DT3 Descripcion: Sanat Alfombra Redonda, de Pelo Largo, Rojo, Moderna, para salón, Dormitorio, Comedor o habitación de los niños, tamaño: 150 x 150 cm. : Amazon.es: Hogar y cocina
# B07MWJZLNS Descripcion: Aktive Garden 53992 - Cenador de Plástico Blanco 300 x 600 x 255 cm con Tubos de Acero: Amazon.es: Jardín
# B09VH2PFCV Descripcion: Movom Galaxy Juego de maletas Verde 55/68/78 cms Rígida ABS Cierre de combinación lateral 217L 11,64 kgs 4 Ruedas dobles Equipaje de Mano : Amazon.es: Equipaje
# B09VH219VL Descripcion: Roll Road Camboya Maleta Grande Negro 53x78x31 cms Rígida ABS Cierre de combinación Lateral 108L 4,76 kgs 4 Ruedas Dobles : Amazon.es: Moda
# B09QQ7L7TP Descripcion: VEVOR Forja de Propano 0-350 psi Horno de Fundición Placa Laminada en Frío 4KG 10min Kit de Horno de Fundición de Metales para Bricolaje, Fábricas de Procesamiento de Joyas, Joyerías, Lavado de Oro : Amazon.es: Hogar y cocina
# B09XVCKVGX Descripcion: Versa Iulia Mesa de Comedor para Cocina, Terraza, Jardín o Comedor, Medidas (Al x L x An) 75 x 80 x 80 cm, Madera, PVC y Metal, Color Marrón y Negro : Amazon.es: Hogar y cocina
# B01MZ615M0 Descripcion: Pro Nappe - Ref R785025I - Mantel no Tejido spunbond desechable - Rollo 50 M de Largo X 1,20 M de Ancho - Color Azul Cielo - Tejido Ripstop, Repelente al Agua y limpiable : Amazon.es: Hogar y cocina
# B0791TSV59 Descripcion: Aktive - Parasol hexagonal Garden diámetro 2,7 m - Mástil de aluminio 38 mm - Color vainilla (ColorBaby 53869): Amazon.es: Jardín
# B081FJCF7P Descripcion: Techwood - Robot ametrina 5L-1000W, color negro : Amazon.es: Hogar y cocina
# B08FRCQGF9 Descripcion: Todocama - Almohada viscoelástica VISCOGEL con Copos 100% viscoelásticos. Tejido Strech Viscogel. Firmeza Media - Alta. (Todas Las Medidas Disponibles). (75 cm) : Amazon.es: Hogar y cocina
# B000PGRVQK Descripcion: Vision Jaula Modelo S01, 45,5 x 35,5 x 51 cm : Amazon.es: Productos para mascotas
# B00DUGZFA6 Descripcion: Amazon Basics - Funda para llevar del hombro ordenador portátil de 11,6 pulgadas (29,4 cm) e iPad, negro, 1 unidad : Amazon.es: Informática
# B08LDPR6KX Descripcion: Cecotec Plancha de asar eléctrica Tasty&Grill 2000 Bamboo MixStone. 2000 W, Estructura Bambú, Termostato regulable, Superficie mixta Grill y plancha, Revestimiento RockStone, Apta lavavajillas : Amazon.es: Hogar y cocina
# B092J3Z3C3 Descripcion: Cecotec Ventilador de Pie con Temporizador EnergySilence 1010 ExtremeFlow. 60 W, 10 aspas, Potente, Oscilante, Silencioso, 3 velocidades, Regulable, Motor de Cobre, Blanco : Amazon.es: Hogar y cocina
# B083CBH2R9 Descripcion: Compra Jocca - Tabla de cortar de polietileno para cocina | Muy resistente | Patas antideslizantes | 45x34x5cm | Grosor: 2,5cm en Amazon.es
# B07V3HWG63 Descripcion: Teac TN-3B (Amplificador fonográfico MM EQ Incorporado, Salida Digital USB, Arma tonificadora SAEC, Velocidad de 33 y 45 RPM), Cherry : Amazon.es: Electrónica
# B08JQB68GQ Descripcion: SQlab Manillar 311 FL-X : Amazon.es: Deportes y aire libre
# B00FIE3S34 Descripcion: Silverline Rolluntersetzer, 150kg, 300mm x 500mm : Amazon.es: Industria, empresas y ciencia
# B00JZY9BGQ Descripcion: Silverline 231329 - Cultivador manual para jardín (950 mm): Amazon.es: Jardín
# B084PB2Z2P Descripcion: Maceta Alta 26,6 L Prosperplast Urbi Square Effect de plástico con depósito en Color Gris Claro, 50 (Alto) x 26,5 (Ancho) x 26,5 (Profundo) cms: Amazon.es: Jardín
# B000LFRY08 Descripcion: Silverline Tools SL35 - Escuadra de acero para carpintero (600 x 400 mm) : Amazon.es: Bricolaje y herramientas
# B000NBTUDY Descripcion: Silverline 763607 - Escoba de fibra de coco (457 mm) : Amazon.es: Industria, empresas y ciencia
# B000LFVLZW Descripcion: Silverline 656582 - Mango articulado (1/2" - 600 mm) : Amazon.es: Bricolaje y herramientas
# B09H378FMS Descripcion: Cecotec Robot Aspirador y Fregasuelos Conga 999 Vital. Friega, aspira y Barre a la Vez. 1400 Pa, Programable, Tanque Mixto, 6 Modos, Mando a Distancia, Autonomía 160min : Amazon.es: Hogar y cocina
# B000LFXU4C Descripcion: Silverline 371756 - Lanza de riego (770 mm) : Amazon.es: Jardín
# B01LD0WPPS Descripcion: Lienzos Levante 2 Listones de 80 cm de Largo con sección de 46 x 17 para Montar 2 Lados de un Bastidor para lienzos, Soporte pictórico, Pino, 80 : Amazon.es: Hogar y cocina
# B07Z6T4FXG Descripcion: Vilber Alfombra vinilo, KILIM.3001 DU 01 78X225X0.22 cm : Amazon.es: Hogar y cocina
# B072M6X1TK Descripcion: HELLA 9XW 358 053-221 Cleantech Limpiaparabrisas - WBU22 - Escobilla con hoja plana - para vehic. dirección izquierda - 22" - 550mm - delante - Cant.: 1 : Amazon.es: Coche y moto
# B084D9H4VS Descripcion: Blackpink Kill This Love Maxi 865647 - Póster (61 x 91,5 cm), multicolor : Amazon.es: Hogar y cocina
# B07TJJXYFV Descripcion: VEVOR Destilador de Agua, 21L con Termómetro Conveniente Destilación Filtro Portátil Purificador Destilador de Agua, 4,7 kg Acero Inoxidable Destilador de Agua Máquina para el Agua Destilada Casera : Amazon.es: Hogar y cocina
# B002BSH0EI Descripcion: Silverline 380625 - Juego de desabollador y Extractor de Clavos : Amazon.es: Bricolaje y herramientas
# B016YAJXJ8 Descripcion: Silverline 361253 - Polipasto de tracción (2.000 kg/Cable 3 m) : Amazon.es: Industria, empresas y ciencia
# B08Q4KVC7L Descripcion: Versa Mannheim Mueble para el Baño Auxiliar, Cajonera con 3 cajones para organizar, Almacenaje Moderno y Divertido, Medidas (Al x L x An) 57 x 28 x 15,5 cm, Nylon, Color Blanco : Amazon.es: Hogar y cocina
# B002QRSPFM Descripcion: Silverline - Regla (aluminio, 1 m) : Amazon.es: Industria, empresas y ciencia
# B0061AGO7Q Descripcion: Tayg Lote 90 cajones extraibles B-80, 79 x 55 x 76 mm. : Amazon.es: Bricolaje y herramientas
# B000LG0PMG Descripcion: Silverline 580460 - Accesorio para perforadoras (tamaño: 450mm) : Amazon.es: Bricolaje y herramientas
# B09D7GN9S4 Descripcion: Documento no encontrado
# B081FTNHDH Descripcion: Theo Klein 3310 Aparcamiento Ford de 6 plantas y bucle I Con rampa de carreras, bucle y salto de esquí I Juguetes para niños a partir de 3 años : Amazon.es: Juguetes y juegos
# B007PRWBP8 Descripcion: Orbegozo CP 71132 - Ventilador de techo con luz y mando a distancia, 4 palas, 132 cm de diámetro, 90 W y 3 velocidades, acero inoxidable : Amazon.es: Hogar y cocina
# B06XJ3JFSP Descripcion: MICA Decorations 83558 GARRAFA Cristal Transparente Diego Ø27CMX42CM, Neutro, 1.25 picometer : Amazon.es
# B074HC47DH Descripcion: Stanley – Martillo de carpintero (fibra de vidrio (600gr Áspero) STHT0 – 51312 : Amazon.es: Bricolaje y herramientas
# B089R82TZ1 Descripcion: WeSkate Patinete Niños Patinete de 3 Ruedas Plegables con Ruedas Luminosas y Manillar Ajustables para Niños y Niñas de 3 a 12 Años Multicolor e Impreso (Rosado) : Amazon.es: Juguetes y juegos
# B097CL3FX7 Descripcion: Dormi Locos- Gato, Color Rosa (Concentra 506125) : Amazon.es: Juguetes y juegos
# B083RXJK4M Descripcion: Ibergrif Praga, Sistema Columna de Ducha con Rociador, Alcachofa, Manguera, Barra Ajustable y Soporte, Negro : Amazon.es: Bricolaje y herramientas
# B00GYR8N4S Descripcion: 3B Scientific Cojín Cilíndrico : Amazon.es: Salud y cuidado personal
# B007TIY3RC Descripcion: 3B Scientific Póster explicativo sobre el cerebro humano (en alemán - Das menschliche Gehirn) : Amazon.es: Industria, empresas y ciencia
# B007TIY714 Descripcion: 3B Scientific VR0714UU - Póster anatómico : Amazon.es: Oficina y papelería
# B07DW81P83 Descripcion: SLV luminaria de pie SQUARE POLE 60 / iluminación de exterior para caminos, paredes, entradas, lámpara led de jardín de exterior / E27 IP44 20 W acero inoxidable : Amazon.es: Iluminación
# B00BCJVT4O Descripcion: Sancarlos - Relleno nórdico Platinum,Gama Premium, 100% Plumón de oca seleccionada de Pluma 100% Natural, Densidad 300 g, Cama 105 : Amazon.es: Hogar y cocina
# B00BCJVUC0 Descripcion: Sancarlos - EDREDON NORDICO Plumon Vivaldi Blanco - Densidad 180 g. + 120 g. - - : Amazon.es: Hogar y cocina
# B06Y1871WH Descripcion: Totto - Mochila Escolar (20L) - Crayola : Amazon.es: Equipaje
# B073CXD6ZC Descripcion: Mochilas Escolares, Mochilas Grandes Infantiles Estampados, Incluyen Neceser - Mochilas totto : Amazon.es: Equipaje
# B06Y1MJ81V Descripcion: Totto - Mochila Escolar (20L) - Crayola : Amazon.es: Equipaje
# B073CYFZWT Descripcion: Mochilas Escolares, Mochilas Grandes Infantiles Estampados, Incluyen Neceser - Mochilas totto : Amazon.es: Equipaje
# B09YRZ6GW8 Descripcion: Audio-Technica AT-LPW30 Giradiscos Manual de traccion por Correa : Amazon.es: Instrumentos musicales
# B00BUTYLNC Descripcion: 3B Scientific U15003 Varilla de Soporte : Amazon.es: Oficina y papelería
# B01H73JRGU Descripcion: SUITLINE - Maleta piloto, Equipaje de Mano, Carro de Negocios, Rígida, TSA, ABS, 2 Ruedas : Amazon.es: Equipaje
# B07QDLBTYB Descripcion: TOTTO Mochila para portátil 15,4 - Krimmler : Amazon.es: Equipaje
# B07RY13QDD Descripcion: Totto MA03EXT001-1820G-N01 Mochila con Ruedas para Portátil 14", Pavon : Amazon.es: Informática
# B07JJZ1D1B Descripcion: TOTTO Ma04eco029-1820n-2iq, Mochila Unisex Adult, Multicolor, Talla Única : Amazon.es: Equipaje
# B07GXBKL3K Descripcion: Pikolin Home - Edredón de fibra con tratamiento antiácaros para otoño/invierno de 300 gr transpirable e hipoalergénico : Amazon.es: Hogar y cocina
# B073RGVZZM Descripcion: Pikolin Home - Edredón nórdico de fibra con tratamiento antiácaros DUO 4 Estaciones de 150 + 300 gr válido para cualquier temperatura : Amazon.es: Hogar y cocina
# B001RPW7QC Descripcion: Cando Dispositivo Para Rehabilitación de Los dedos, la Muñeca y el Antebrazo, Amarillo/Más Ligero (X), 36 cm : Amazon.es: Salud y cuidado personal
# B001RY42TS Descripcion: Cando Dispositivo Para Rehabilitación de Los dedos, la Muñeca y el Antebrazo, Verde/Moderado, 36 cm-sin látex : Amazon.es: Deportes y aire libre
# B006LN85QG Descripcion: Cando W54216YG Combi Dispositivo Para Ejercicios de Mano Diametro 35,6 cm, Amarillo/Verde, Más, Ligero (x)/Moderado : Amazon.es: Salud y cuidado personal
# B00DYSJ3YE Descripcion: Taurus 944.628 Boreal 16C - Ventilador (Negro, Gris, 45W) : Taurus: Amazon.es: Hogar y cocina
# B07X5XNS5C Descripcion: Eysa Levante Funda de sofá, Algodón, Agua Marina, 240 CM. Izquierda : Amazon.es: Hogar y cocina
# B0002E58DS Descripcion: ART TPSIICE - Preamplificador a válvulas : Amazon.es: Instrumentos musicales
# B000C74W6E Descripcion: Stanley 2-15-595 - Serrucho JetCut Fine 450mm x 11 : Amazon.es: Bricolaje y herramientas
