# %%
#tiempo en milisegundos


import datetime as dt

year = dt.datetime.now().year
month = dt.datetime.now().month
day = dt.datetime.now().day
hour = dt.datetime.now().hour+3
minute = dt.datetime.now().minute



date_time = dt.datetime(year, month, day, hour, minute)
timestamp = int(date_time.timestamp() * 1000)
print(timestamp)  # 1727966400000

# %%
from datetime import datetime

year = datetime.now().year
month = datetime.now().month
day = datetime.now().day
hour = datetime.now().hour
minute = datetime.now().minute

date_time = dt.datetime(year, month, day, hour, minute)
print(date_time)

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
#from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait as wait

import time, base64

# ****** URL DE PRODUCCION ******
url = "http://10.19.6.177:8080/reflex/env/puma_es_dev"
 
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver_options = Options()
driver_options.add_argument(headers)
driver_options.add_argument('--no-sandbox')

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
#driver.execute_script("window.scrollTo(500, 1080);")

time.sleep(5)

#loguear

decoded_user = base64.b64decode("amdhcmNpYW1lcmFz")
decoded_pw = base64.b64decode("VHJvbmtpdGEwOA==")

user = decoded_user.decode("utf-8")
passw = decoded_pw.decode("utf-8")

user_login = driver.find_element("xpath", "/html/body/div[4]/div/input[1]").send_keys(user)
user_passw = driver.find_element("xpath", "/html/body/div[4]/div/input[2]").send_keys(passw)
user_passw = driver.find_element("xpath", "//*[@id='login_ok']").click()

time.sleep(7)

#acceder al menú correspondiente

driver.find_element("xpath", "/html/body/div[1]/div/div[1]/div[5]/div[1]/div").click()
time.sleep(5)

#inventario - menu
driver.find_element("xpath", "/html/body/div[2]/div[1]/div[1]/div[6]/div[4]/div[2]/div[3]/div/div[2]/div[10]/div[2]").click()
time.sleep(3)

#tocar opcion inventario
driver.find_element("xpath", "/html/body/div[2]/div[1]/div[1]/div[6]/div[4]/div[2]/div[3]/div/div[2]/div[10]/div[2]/div[2]").click()
time.sleep(3)

#toca all
driver.find_element("xpath", "/html/body/div[2]/div[1]/div[1]/div[13]/div[4]/div[7]/fieldset/span[1]").click()
time.sleep(3)

#toca JG_TEST_10
driver.find_element("xpath", "/html/body/div[2]/div[1]/div[1]/div[13]/div[4]/div[14]/div[2]/div/div[6]/table/tr/td[5]").click()
time.sleep(3)

#toca OK
driver.find_element("xpath", "/html/body/div[2]/div[1]/div[1]/div[13]/div[4]/button[3]/div").click()

print("Proceso terminado")

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\jgmeras\Documents\Python Scripts\6. CABANILLAS\Mturn

# %%
import datetime as dt

year = dt.datetime.now().year
month = dt.datetime.now().month
day = dt.datetime.now().day
print(f"Year: {year}")
print(f"Month: {month}")
print(f"Day: {day}")
# Out:
# Year: 2024
# Month: 12
# Day: 18

# %%
import os
import tkinter as tk
from tkinter import ttk
from textwrap import wrap

def ajustar_texto(texto, ancho_maximo):
    # Dividir el texto en líneas con el ancho máximo
    return "\n".join(wrap(texto, width=ancho_maximo))

def procesar_directorio(directorio):
    try:
        # Verificar si el directorio existe
        if not os.path.isdir(directorio):
            raise FileNotFoundError(f"El directorio '{directorio}' no existe.")
        
        # Listar el contenido del directorio
        contenido = os.listdir(directorio)
        
        # Filtrar solo directorios
        solo_directorios = [d for d in contenido if os.path.isdir(os.path.join(directorio, d))]
        
        if not solo_directorios:
            raise ValueError("No se encontraron subdirectorios en el directorio dado.")
        
        # Tomar el primer directorio
        primer_directorio = solo_directorios[0]
        
        # Separar el primer directorio en dos partes
        cadena = primer_directorio[:-4] if len(primer_directorio) > 4 else ""
        ultimos_cuatro = list(primer_directorio[-4:])
        
        # Crear la lista de últimos cuatro caracteres de todos los directorios
        ultimos_caracteres = set()
        for d in solo_directorios:
            if len(d) >= 4:
                ultimos_caracteres.add(d[-4:])
        
        # Ordenar la lista en orden descendente y convertirla en lista
        lista_ordenada = sorted(ultimos_caracteres, reverse=True)
        
        return lista_ordenada, cadena
    except Exception as e:
        return str(e)

def seleccionar_ano():
    usuario = os.environ['USERNAME']
    directorio = f"C:\\Users\\{usuario}\\GXO\\SPCABANILLAS - Cabanillas_Electrolux\\6. Stock\\1. FICHEROS HISTORICOS"
    lista_anos, direccion = procesar_directorio(directorio)
    #print("Lista:", lista_anos)
    #print("Cadena:", direccion)
    texto_ajustado = ajustar_texto(direccion, ancho_maximo=30)
    app_ano = tk.Tk()
    app_ano.title("Seleccionar Año")
    app_ano.geometry("300x200")
    
    label = tk.Label(
        app_ano,
        text=f"{texto_ajustado}",
        foreground="black",
        font=("Arial", 12, "bold"),
        
    )
    label.pack(pady=10)
    
    combo = ttk.Combobox(
        app_ano,
        values=lista_anos
        )
    combo.pack(pady=10)
    
    button_ok = tk.Button(
        app_ano,
        text="OK",
        command=lambda: print(combo.get()),
        width=18
    )
    button_ok.pack(pady=10)
    
    button_exit = tk.Button( 
        app_ano,
        text="Salir",
        command=app_ano.destroy,
        width=18,
        foreground="red"        
        
    )
    button_exit.pack(pady=10)
    


    app_ano.mainloop()
    

    
    
seleccionar_ano()
# Out:
# 2024
