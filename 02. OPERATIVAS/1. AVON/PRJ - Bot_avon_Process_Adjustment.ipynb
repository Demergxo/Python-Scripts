# %% [markdown]
# # **INSTALAR REPOSITORIOS NECESARIOS**

# %%
#anaconda prompt > pip install selenium
#anaconda prompt > conda install -c anaconda openpyxl

from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys

import time
import base64
import tkinter as tk
from tkinter import messagebox as mb

import urllib.request, urllib.error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **FUNCIONES**

# %%
def loguear_defecto():
    """ Loguear con un usuario predeterminado"""
    #loguear

    decoded_user = base64.b64decode("anBhbGFjaW9z")
    decoded_pw = base64.b64decode("U2VjdXJpdHlAMTIzNA==")

    user = decoded_user.decode("utf-8")
    passw = decoded_pw.decode("utf-8")

    driver.find_element("xpath", "//*[@id='UserId']").send_keys(user)
    driver.find_element("xpath", "//*[@id='Psw']").send_keys(passw)
    driver.find_element("xpath", "//*[@id='Psw']").send_keys(Keys.RETURN)
    time.sleep(10)

def acceder_Adjustment():
    """Acceso al menú de Adjustment"""
    #definir delay
    delay = 5 #seconds
    #acceder al menú de Inventory-Adjustment

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon").click()

    time.sleep(1)

    try: 
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[2]/a/span[2]").click()
    except: 
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon").click()
        time.sleep(1)
        driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[2]/a/span[2]").click()
    
    time.sleep(2)

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[2]/div/xpo-vertical-tab-group[1]/a/span[2]").click()

    time.sleep(2)

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[2]/div/xpo-vertical-tab-group[1]/div/a[2]/span[2]").click()

    time.sleep(3)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon").click()
    #Tocar cliente y seleccionarlo
    
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[4]/div/app-wmx-multi-select/ss-multiselect-dropdown/div/button").click()
    time.sleep(1)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[4]/div/app-wmx-multi-select/ss-multiselect-dropdown/div/div/a[4]").click()
    time.sleep(1)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[5]/div/input").click()
    
    #Tocar Status y 101
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[13]/div/app-wmx-multi-select/ss-multiselect-dropdown/div/button").click()
    time.sleep(1)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[13]/div/app-wmx-multi-select/ss-multiselect-dropdown/div/div/a[4]/span/span").click()
    time.sleep(1)

    #Tocar en otro punto
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[9]/div/input").click()
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[9]/div/input").send_keys(Keys.ENTER)
    time.sleep(12)

    """ try:
        WebDriverWait(poll_frequency=delay).until(EC.presence_of_element_located("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[1]/div[2]/mat-checkbox/label/span[1]"))
    except:
        time.sleep(7) """
    
    #Tocar todos y Process
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/form/div/table/thead/tr/th[1]/div[2]/mat-checkbox/label/span[1]").click()
    time.sleep(1)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[1]/div/div/div[2]/div/div/wmx-button[1]/button/span[1]").click()
    time.sleep(1)

    #Boton Save y process
    time.sleep(5)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-multi-adjust/div/div/div[1]/app-sub-header/xpo-card/xpo-card-header/xpo-card-title/div[1]/div[2]/div/div/div[1]/wmx-button/button/span[1]").click()
    time.sleep(7)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-multi-adjust/div/div/div[1]/app-sub-header/xpo-card/xpo-card-header/xpo-card-title/div[1]/div[2]/div/div/div[2]/wmx-button/button/span[1]").click()

    #popup and yes
    time.sleep(2)
    driver.find_element("xpath", "/html/body/modal-container/div/div/app-confirmation-modal/form/div/div[2]/div/wmx-button[1]/button/span[1]").click()

    time.sleep(2)
    driver.findelement("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[1]/div/div/div[2]/div/div/wmx-button[1]/button/span[1]").click()

    texto.configure(text='En progreso')


def process_adjustment():
    
    try:
        driver.findelement("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-inventory-adjust-list/div/div/div/wx-search-controller/div[2]/div/div[2]/div[2]/div/nav/ul/li[6]/button").click()
    except:
        return False
        
    return True

def loguear_personalizado():
    """Loguear con usuarios personales sin guardar registro"""
    def enviar():
        """Comprobar si alguna de las cadenas está vacia, si no pasa los datos"""
        if dato1.get()==str("") or dato2.get()==str(""):
            mb.showerror("ATENCION!!", "No se puede dejar un campo sin rellenar")
        else:
            user = dato1.get()
            passw = dato2.get()
            driver.find_element("xpath", "//*[@id='UserId']").send_keys(user)
            driver.find_element("xpath", "//*[@id='Psw']").send_keys(passw)
            driver.find_element("xpath", "//*[@id='Psw']").send_keys(Keys.RETURN)
            print(user)
            print(passw)
            
            ventana1.destroy()


    ventana1=tk.Tk()
    ventana1.title('Logueo')
    labelframe1 = tk.LabelFrame(ventana1, text="Login")
    labelframe1.grid(column=0, row=0, padx=10, pady=10)
    ventana1.geometry('300x200')

    label1=tk.Label(labelframe1, text="Usuario")
    label1.grid(column=0, row=0, padx=5, pady=5, sticky="e")
    dato1 =tk.StringVar()
    entry1 = tk.Entry(labelframe1, textvariable=dato1)
    entry1.grid(column=1, row=0, padx=5, pady=5)
    label2 = tk.Label(labelframe1, text="Password")
    label2.grid(column=0, row=1, padx=0, pady=0, sticky="e")
    dato2= tk.StringVar()
    entry2 = tk.Entry(labelframe1, textvariable=dato2, show="*")
    entry2.grid(column=1, row=1, padx=5, pady=5)
    boton1 =tk.Button(labelframe1, text="Enviar", command=enviar)
    boton1.grid(column=1, row=2, padx=5, pady=5, sticky="we")

    ventana1.bind('<Return>', func=enviar)

    ventana1.mainloop()

    time.sleep(1)

def en_progreso():
    texto.configure(text='En progreso')

# %% [markdown]
# # **CONFIGURAR Y CREAR ENTORNO GRAFICO**

# %%
#Creamos la ventana principal
ventana = tk.Tk()
ventana.title('Procesos Avon')
ventana.geometry('400x300')

#Creamos barra de menus
barra_menus = tk.Menu(ventana)
ventana.config(menu=barra_menus)

#Creamos menus para la barra

menu = tk.Menu(barra_menus, tearoff=False, title="Procesos")
submenu = tk.Menu(menu, tearoff=False)
submenu2 = tk.Menu(menu, tearoff=False)

#Añadimos las opciones a los menus
submenu.add_command(label='Loguear con usuario predeterminado', command=loguear_defecto)
submenu.add_command(label='Loguear con usuario personalizado', command=en_progreso)
menu.add_cascade(label='Loguear', menu=submenu)
menu.add_command(label='Procesar Ajustes', command=acceder_Adjustment)

#Creamos menu salida y linea separadora
menu.add_separator()
menu.add_command(label='Salir', command=ventana.destroy)

#añadimos el menuú a la barra

barra_menus.add_cascade(label='Procesos', menu=menu)

#Añadimos etiqueta
texto = tk.Label(ventana, text='Proceso ajustes Avon', font=('Arial', 18))
texto.place(x=90, y=100)

# %% [markdown]
# # **LANZAR NAVEGADOR Y FUNCIONES PRINCIPALES**

# %%
if __name__ == '__main__':
    
   # *****URL DE PRUEBAS *****
   url = "http://mad001.qa.wmx.sc.xpo.com" 

   # ****** URL DE PRODUCCION ******
   #url = "http://mad001.wmx.sc.xpo.com"

   headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

   driver_options = Options()
   driver_options.add_argument(headers)
   driver_options.add_argument('--no-sandbox')

   driver = webdriver.Chrome()
   driver.maximize_window()
   driver.get(url)
   #driver.execute_script("window.scrollTo(500, 1080);")

   ventana.mainloop()
