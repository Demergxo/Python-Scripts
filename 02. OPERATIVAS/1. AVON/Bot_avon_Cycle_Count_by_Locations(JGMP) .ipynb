# %% [markdown]
# # **INSTALAR REPOSITORIOS NECESARIOS**

# %%
#anaconda prompt > pip install selenium
#anaconda prompt > conda install -c anaconda openpyxl

from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys

import openpyxl
import time
import os
import base64
import re

import urllib.request, urllib.error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **FUNCIONES**

# %%
#pasar pantallas hasta de conteo hasta conteo de material

def cycc1(sku_mad):
    #print("cycc1")
    
    
    driver.find_element("xpath", "//*[@id='skuConf']").send_keys(sku_mad)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[2]/div[2]/span").click()

    time.sleep(7)

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/form/div[4]/div[2]/button/span[1]").click()

    time.sleep(5)




#rellenar campos en pantalla uncounted

def fill_fields_uncounted(check_item):
    
    
#     loc_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[2]/div[2]/span").text
#     batch_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[4]/div[2]/span").text
    
    
    result = 0
    if check_item == 0:
        
            form_clear_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").get_attribute("input")
            
            if form_clear_url == None:
                time.sleep(1)
                driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").clear()

                while result <= (row_limit+1):
                    time.sleep(5)
                    

                    for i in range(first_sku_row, row_limit + 1):

                        loc_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[2]/div[2]/span").text
                        batch_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[4]/div[2]/span").text
                        lpn_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[17]/div[2]/span").text
                        sku = sheet_obj.cell(row = i, column = sku_col).value
                        cant = sheet_obj.cell(row = i, column = cantidad_col).value
                        loc = sheet_obj.cell(row = i, column = location_col).value
                        lpn = sheet_obj.cell(row = i, column = lpn_col).value
                        batch = sheet_obj.cell(row =i, column = batch_col).value
                        check = sheet_obj.cell(row =i, column = check_col).value
                        if lpn == None:
                            lpn_check = ""
                        
                        if (not is_number(lpn)) or lpn == None:
                            lpn_check = lpn
                            #print(lpn_check)
                            

                        if is_number(lpn):
                            n = re.search(pattern, str(lpn))
                            lpn_check = str(lpn).zfill(10)
                            #print(lpn_check)
                        
                        if lpn_check == None:
                            lpn_check = ""
                            
                        if batch == None:
                            batch = ""
        
                        print("LPN: "+ str(lpn_check) + " LPN url: " + lpn_url)
                       
                        if loc == loc_url and batch == batch_url and str(lpn_check) == lpn_url:
                            
                            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").clear()
                            print("VUELTA: "+str(i)+" SKU: "+sku+ " CANT: "+str(cant)+ " LOC: "+ loc+ " BATCH: "+str(batch))
                            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[20]/div/mat-form-field/div/div[1]/div/input").send_keys(cant)
                            time.sleep(5)
                            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[21]/button").click()
                            time.sleep(5)
                            sheet_obj.cell(row =i, column = check_col).value = 1
                            check_check = sheet_obj.cell(row =i, column = check_col).value
                            for index in range(first_sku_row, row_limit + 1):
                                result =+ check_check

    time.sleep(5)    



#confirmar cambios de ubicacion

def change_location(sku_item, location):
    print("change location")
    loc_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[1]/div[2]/span").text
    sku_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[3]/div[2]/div[2]/span").text
    print("location url: " + loc_url + " location: " + location)
    #print("sku url: "+ sku_url + " sku: " + sku_item)
    
    
    if location == loc_url:
        if sku_item == sku_url:
            driver.find_element("xpath", "//*[@id='skuConf']").send_keys(sku_item)
            time.sleep(3)
            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[2]/div[1]/button/span[1]").click()
    time.sleep(5)        
            
# saber si es un numero o no
  

def is_number(lpn):
    if lpn == None:
        lpn = ""  
    
    try:
        int(lpn)
    except ValueError:
        return False
    return True

#entrar en la primera pantalla


#pasar al segundo sku
        
def other_sku(first_sku_row, sku_col, row_limit):
    
    print("CHECKPOINT 2")

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[1]/button/span/span").click()
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[2]/div/mat-button-toggle[3]/button/span/span").click()
    time.sleep(5)

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[1]/mat-form-field/div/div[1]/div/mat-select/div/div[2]/div").click()
    driver.find_element("xpath", "/html/body/div[2]/div[2]/div/div/div/mat-option[2]/span").click()
    time.sleep(5)



    for i in range(first_sku_row, row_limit + 1):
    #asignamos valores a las variables

        j = i+1

        sku = sheet_obj.cell(row = i, column = sku_col).value
        sku2 =sheet_obj.cell(row = j, column = sku_col).value

        if sku != sku2 and sku2 != None:

            driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[2]/mat-form-field/div/div[1]/div/input").send_keys(sku2)
            second_sku(sku2)
        if sku2 == None:
            break



    time.sleep(5)

#ingresar el segundo sku

    
def second_sku(sku):
    
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[4]/button/span[1]").click()
    time.sleep(5)


    driver.find_element("xpath", "//*[@id='skuConf']").send_keys(sku)
    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[2]/div[2]/span").click()

    time.sleep(10)

    driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/form/div[4]/div[2]/button/span[1]").click()

def test_check(first_sku, row_limit):
    
    result = 0
    
    for i in range(first_sku, row_limit + 1):
        
        check = sheet_obj.cell(row =i, column = check_col).value
        
        if check == "Y":
            result += 1
    
    return result


#Cargar una lista con todos los Sku
def fill_sku_list(first_sku_row, article_col, row_limit):
    fill_list= []
    for name in range(first_sku_row, row_limit+1):
        fill_list.append(sheet_obj.cell(row=name, column=article_col).value)
        fill_list = list(dict.fromkeys(fill_list))
    return fill_list

# %% [markdown]
# # **CONFIGURAMOS EL NAVEGADOR**

# %%
# *****URL DE PRUEBAS *****
#url = "http://m.mad001.qa.wmx.sc.xpo.com" 

# ****** URL DE PRODUCCION ******
url = "http://m.mad001.wmx.sc.xpo.com"
 
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

driver_options = Options()
driver_options.add_argument(headers)
driver_options.add_argument('--no-sandbox')

driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)
#driver.execute_script("window.scrollTo(500, 1080);")

time.sleep(20)

# %% [markdown]
# # **LLEGAR HASTA EL MENÚ DE CONTEO CÍCLICO**

# %%
#loguear

decoded_user = base64.b64decode("amdtZXJhcw==")
decoded_pw = base64.b64decode("U2VjdXJpdHlAMTIzNA==")

user = decoded_user.decode("utf-8")
passw = decoded_pw.decode("utf-8")

user_login = driver.find_element("xpath", "//*[@id='UserId']").send_keys(user)
user_passw = driver.find_element("xpath", "//*[@id='Psw']").send_keys(passw)
user_passw = driver.find_element("xpath", "//*[@id='Psw']").send_keys(Keys.RETURN)

time.sleep(10)

#acceder al menú de conteo ciclico

wmx_menu = driver.find_element("xpath", "/html/body/app-root/xpo-shell/header/div[1]/xpo-header-hamburger/xpo-icon").click()

time.sleep(5)

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[4]/a/span[2]").click()

time.sleep(5)

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer/div/div/nav/xpo-vertical-tab-group[4]/div/a[6]/span[2]").click()

time.sleep(5)

# %% [markdown]
# # **PREPARAR EXCEL (SIEMPRE TENERLO CERRADO)**

# %% [markdown]
# # **RECORDAR BUSCAR EN INV BALANCE EL SKU Y RELLENAR EL EXCEL**
# # **MUY IMPORTANTE: QUITAR ESPACIOS EN BLANCO**

# %%
#Incluir la localizacion del fichero excel con los datos
current_directory = os.getcwd()
path = current_directory + "\AvonCCycle.xlsx"


# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column

print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)
print("Proceso de preparacion de Excel finalizado")

#Introducir el numero de columna en la que se encuentra el SKU (A=1, B=2, C=3...)
sku_col = 4

#Introducir el numero de la fila en la que se encuentra el primer valor de SKU
first_sku_row = 2

#Introducir el numero de columna en la que se encuentra la cantidad a introducir
cantidad_col = 5

#Introducir el numero de columna en el que se encuentra la ubicacion
location_col = 2

#Introducir numero de columna en el que se encuentra el lote
batch_col = 8

#Introducir numero de columna de verificación
check_col= 9

#Introducir numero de columna de LPN
lpn_col = 3

time.sleep(3)

# %% [markdown]
# # **ENTRAR AL CONTEO CÍCLICO**

# %%
#tocar CC1, SKU e introducir el codigo

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[1]/button/span/span").click()
driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[2]/div/mat-button-toggle[1]/button/span/span").click()

time.sleep(5)

sku_mad = sheet_obj.cell(row = first_sku_row, column = location_col).value
sku_init = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[3]/div/div[3]/mat-form-field/div/div[1]/div/input").send_keys(sku_mad)
time.sleep(5)
driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[4]/button/span[1]").click()

time.sleep(10)

#entrar en menu de conteo por localización

driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[1]/div/mat-form-field/div/div[1]/div/input").send_keys(sku_mad)
time.sleep(1)
driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/form/div[2]/div[1]/button").click()

time.sleep(3)
driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-summary-execution/div/div/form/div[6]/div/button").click()

# %% [markdown]
# # **LECTURA Y ESCRITURA EN WEB**

# %%
#creamos el bucle para que vaya leyendo del excel y rellene el formulario

result = 0
pattern = r"([\d+])"

while result <= (row_limit + 1):

    try:
        ch1 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[1]/button/span/span").text
        ch2 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[2]/button/span/span").text
        ch3 = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/div[2]/form/div[1]/div/mat-button-toggle-group/mat-button-toggle[3]/button/span/span").text
        check = ch1+ch2+ch3
        if check == "CYCC1CYCC2CYCC3":
            break
    except:
        pass

    print("RESULT: " + str(result))  
    for i in range(first_sku_row, row_limit + 1):
        #asignamos valores a las variables
        
        sku = sheet_obj.cell(row = i, column = sku_col).value
        cant = sheet_obj.cell(row = i, column = cantidad_col).value
        loc = sheet_obj.cell(row =i, column = location_col).value
        batch = sheet_obj.cell(row =i, column = batch_col).value
        lpn = sheet_obj.cell(row = i, column = lpn_col).value
        check = sheet_obj.cell(row =i, column = check_col).value
        
        if lpn == None:
            lpn_check = ""
            
        if (not is_number(lpn)) or lpn == None:
            lpn_check = lpn
         
        if is_number(lpn):
            n = re.search(pattern, str(lpn))
            lpn_check = str(lpn).zfill(10)
            
       
        
       
        #comprobamos el cabecero de la pagina
        try:
            if lpn_check == None:
                lpn_check = ""
        
            if batch == None:
                batch = ""
            
            
            tittle_url = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/div[1]/span").text  
            print("**COMPROBACION 1 TRY: " + str(i) +" SKU: " + str(sku) + " Cant: " + str(cant) + " Loc: " + str(loc) + " Batch: " + str(batch))
            if tittle_url == "LOT Count":
                lot_count = driver.find_element("xpath", "/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-lot-execution/div/div/form/div[4]/div[2]/button/span[1]").click()
                time.sleep(5)
            if tittle_url == "Directed LOT Count":
                print('ADVERTENCIA', 'SEGUNDO CONTEO CÍCLICO')
                time.sleep(3)
                

        except:

            try:
                if lpn_check == None:
                    lpn_check = ""
        
                if batch == None:
                    batch = ""
                
                
                tittle_url = driver.find_element("xpath","/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-uncounted-material/div/div/div[1]/span[1]").text
                
                if tittle_url == "Uncounted Material":
                    print("**COMPROBACION 2 TRY: " + str(i) +" SKU: " + str(sku) + " Cant: " + str(cant) + " Loc: " + str(loc) + " Batch: " + str(batch) + " LPN: " + str(lpn_check))
                    fill_fields_uncounted(check)
                    
                    sheet_obj.cell(row =i, column = check_col).value = "Y"
                    confirm = sheet_obj.cell(row =i, column = check_col).value
                    
                    print(("COMPROBACION 2 CONFIRM, CELDA {},{}: {}, {} ").format(str(i), str(check_col), str(check), str(confirm)))
                    time.sleep(5)

            except:
                try:
                    if lpn_check == None:
                        lpn_check = ""
        
                    if batch == None:
                        batch = ""
                    
                    
                    tittle_url = driver.find_element("xpath","/html/body/app-root/xpo-shell/xpo-tab-drawer/mat-drawer-container/mat-drawer-content/xpo-tab-drawer-content/app-cycle-count/div/app-cycle-count-confirmation/div/div/div[6]/div[2]/span").text
                    
                    if tittle_url == "CYCC1":
                        print("**COMPROBACION 3 TRY: " + str(i) +" SKU: " + str(sku) + " Cant: " + str(cant) + " Loc: " + str(loc) + " Batch: " + str(batch))
                        change_location(sku, loc)
                        time.sleep(5)
                except:
                    try:
                        if lpn_check == None:
                            lpn_check = ""
        
                        if batch == None:
                            batch = ""
                        
                        cycc1()
                        print("**COMPROBACION 4 TRY: " + str(i) +" SKU: " + str(sku) + " Cant: " + str(cant) + " Loc: " + str(loc) + " Batch: " + str(batch))
                        time.sleep(5)
                    except:
                        
                        print("**COMPROBACION EXCEPT: " + str(i) +" SKU: " + str(sku) + " Cant: " + str(cant) + " Loc: " + str(loc) + " Batch: " + str(batch))
                        break
                        

            result = test_check(first_sku_row, (row_limit +1))
        time.sleep(5)
        print(("Result : {}").format(str(result)))

                
try:
    wb_obj.save(path)
except:
    print("NO SE PUDO GUARDAR EL LIBRO CON EXITO")
    
print("SCRIPT FINALIZADO CON EXITO")
