# %% [markdown]
# ## Imports

# %%
#anaconda prompt > conda install -c anaconda openpyxl

import openpyxl

from bs4 import BeautifulSoup
import requests
import time
import datetime
import os



import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Funcion para extraccion de datos de Nike

# %%
# Conectar y obtener datos desde Nike

#Se obtiene el User Agent desde http://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

#Funcion para obtener el precio de un producto
def get_Nike_price(url):

    #Se obtiene el HTML del producto
    page = requests.get(url, headers=headers, verify=False)
    soup1 = BeautifulSoup(page.content, "html.parser")

    #Se extrae el precio del HTML
    try:
        price = soup1.find('div', {"class": "product-price es__styling is--current-price css-11s12ax"}).text.strip()
               
    except:
        try:
            price = soup1.find('div', {"class" : "product-price is--current-price css-1ydfahe"}).text.strip() 
                
        except AttributeError:
            price = "No se ha podido obtener el precio para este producto."
        
    return price

# %% [markdown]
# ## Configuracion del Excel

# %%
#Incluir la localizacion del fichero excel con los datos de Nike:
directory = os.getcwd()
path = directory + "\\Precios.xlsx"

# Se abre el workbook y la hoja seleccionados (donde se guardo el documento por ultima vez)
wb_obj = openpyxl.load_workbook(path)
sheet_obj = wb_obj.active

# Obtener el numero de filas y columnas usadas
row_limit = sheet_obj.max_row
column_limit = sheet_obj.max_column
  
print("Total de filas:", row_limit)
print("Total de columnas:", column_limit)

#Introducir el numero de columna en la que se encuentra el SKU (A=1, B=2, C=3...)
sku_col = 1

#Introducir el numero de la fila en la que se encuentra el primer valor de sku
first_sku_row = 2

#Introducir el numero de columna en la que se encuentra el precio
precio_col = 4
# Out:
# Total de filas: 4704
# Total de columnas: 5

# %%
# Cerrar el fichero Excel antes de ejecutar esta celda

#Introducir el formato de la web que se va a buscar
web_prefix = "https://www.nike.com/es/w?q="



for i in range(first_sku_row, row_limit + 1): 
    cell_obj = sheet_obj.cell(row = i, column = sku_col)
    sku = str(cell_obj.value)
    
    if sku == None:
        sku = ""
    
    #sku = str(sku).zfill(12)
    
    url = web_prefix+sku
    try:
        price = get_Nike_price(url)
        print(("{}: {} tiene un precio de: {}").format(i, sku, price))
    
        #Se introduce el precio en el Excel
        c1 = sheet_obj.cell(row = i, column = precio_col)
        c1.value = price
    except:
        break
    
#Se guarda el fichero Excel con los cambios aplicados
wb_obj.save(path)
print("ARCHIVO GUARDADO / PROGRAMA FINALIZADO")
# Out:
# 2: DA5382-102 tiene un precio de: 39,99 €
# 3: DA5382-104 tiene un precio de: 31,47 €
# 4: DA5536-100 tiene un precio de: 39,99 €
# 5: DA5556-010 tiene un precio de: 49,99 €
# 6: DA5556-063 tiene un precio de: 31,47 €
# 7: DA5711-010 tiene un precio de: 74,99 €
# 8: DA5711-100 tiene un precio de: 74,99 €
# 9: DA5711-379 tiene un precio de: 41,97 €
# 10: DA5711-638 tiene un precio de: 41,97 €
# 11: DA5718-010 tiene un precio de: 19,99 €
# 12: DA5718-011 tiene un precio de: No se ha podido obtener el precio para este producto.
# 13: DA5718-100 tiene un precio de: 19,99 €
# 14: DA6364-101 tiene un precio de: 94,99 €
# 15: DA6506-657 tiene un precio de: 34,99 €
# 16: DA6918-010 tiene un precio de: 24,99 €
# 17: DA6918-100 tiene un precio de: 24,99 €
# 18: DA6925-102 tiene un precio de: 22,99 €
# 19: DA6976-010 tiene un precio de: 39,99 €
# 20: DA7245-001 tiene un precio de: 159,99 €
# 21: DA7245-007 tiene un precio de: No se ha podido obtener el precio para este producto.
# 22: DA7245-010 tiene un precio de: 159,99 €
# 23: DA7245-011 tiene un precio de: 159,99 €
# 24: DA7245-401 tiene un precio de: No se ha podido obtener el precio para este producto.
# 25: DA7337-010 tiene un precio de: 34,99 €
# 26: DA7337-870 tiene un precio de: 34,99 €
# 27: DA7505-620 tiene un precio de: 11,99 €
# 28: DA7507-010 tiene un precio de: 11,99 €
# 29: DA7698-001 tiene un precio de: 159,99 €
# 30: DA7698-005 tiene un precio de: 159,99 €
# 31: DA7698-009 tiene un precio de: 89,97 €
# 32: DA7995-001 tiene un precio de: 49,97 €
# 33: DA7995-100 tiene un precio de: 54,97 €
# 34: DA7995-104 tiene un precio de: 109,99 €
# 35: DA8026-002 tiene un precio de: 99,99 €
# 36: DA8026-100 tiene un precio de: 99,99 €
# 37: DA8026-331 tiene un precio de: No se ha podido obtener el precio para este producto.
# 38: DA8032-030 tiene un precio de: 109,99 €
# 39: DA8535-001 tiene un precio de: 129,99 €
# 40: DA8535-008 tiene un precio de: 129,99 €
# 41: DA8535-010 tiene un precio de: 129,99 €
# 42: DA8535-102 tiene un precio de: No se ha podido obtener el precio para este producto.
# 43: DA8535-401 tiene un precio de: No se ha podido obtener el precio para este producto.
# 44: DA8570-001 tiene un precio de: 129,99 €
# 45: DA8570-004 tiene un precio de: No se ha podido obtener el precio para este producto.
# 46: DA8570-105 tiene un precio de: 119,99 €
# 47: DA8570-400 tiene un precio de: No se ha podido obtener el precio para este producto.
# 48: DA8570-600 tiene un precio de: 129,99 €
# 49: DA8697-400 tiene un precio de: No se ha podido obtener el precio para este producto.
# 50: DA8723-002 tiene un precio de: 52,47 €
# 51: DA9820-687 tiene un precio de: 64,99 €
# 52: DA9826-010 tiene un precio de: 31,97 €
# 53: DA9826-091 tiene un precio de: 31,97 €
# 54: DA9826-687 tiene un precio de: 31,97 €
# 55: DB0192-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 56: DB0306-010 tiene un precio de: 32,99 €
# 57: DB0456-010 tiene un precio de: 24,99 €
# 58: DB0456-382 tiene un precio de: 19,99 €
# 59: DB0456-460 tiene un precio de: No se ha podido obtener el precio para este producto.
# 60: DB0488-010 tiene un precio de: 22,99 €
# 61: DB0488-410 tiene un precio de: No se ha podido obtener el precio para este producto.
# 62: DB0488-663 tiene un precio de: 22,99 €
# 63: DB0490-010 tiene un precio de: 22,99 €
# 64: DB0490-382 tiene un precio de: 22,99 €
# 65: DB0490-460 tiene un precio de: 22,99 €
# 66: DB1181-728 tiene un precio de: 74,99 €
# 67: DB1184-323 tiene un precio de: 74,99 €
# 68: DB1194-011 tiene un precio de: 74,99 €
# 69: DB1210-481 tiene un precio de: No se ha podido obtener el precio para este producto.
# 70: DB1212-496 tiene un precio de: 74,99 €
# 71: DB2179-003 tiene un precio de: No se ha podido obtener el precio para este producto.
# 72: DB2179-004 tiene un precio de: 99,99 €
# 73: DB2179-006 tiene un precio de: 99,99 €
# 74: DB2179-109 tiene un precio de: 99,99 €
# 75: DB2179-111 tiene un precio de: 99,99 €
# 76: DB3300-010 tiene un precio de: 47,99 €
# 77: DB3300-258 tiene un precio de: 42,99 €
# 78: DB3551-001 tiene un precio de: 53,97 €
# 79: DB3551-100 tiene un precio de: 53,97 €
# 80: DB3552-100 tiene un precio de: 41,97 €
# 81: DB3553-100 tiene un precio de: 35,97 €
# 82: DB5471-010 tiene un precio de: 34,99 €
# 83: DB5471-100 tiene un precio de: 34,99 €
# 84: DB5612-010 tiene un precio de: 37,99 €
# 85: DB5896-406 tiene un precio de: 53,97 €
# 86: DB5900-011 tiene un precio de: 44,97 €
# 87: DB5935-010 tiene un precio de: 38,97 €
# 88: DB5935-100 tiene un precio de: 38,97 €
# 89: DB6080-010 tiene un precio de: 41,97 €
# 90: DB6223-406 tiene un precio de: 44,97 €
# 91: DB6481-051 tiene un precio de: No se ha podido obtener el precio para este producto.
# 92: DB6512-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 93: DB6512-333 tiene un precio de: No se ha podido obtener el precio para este producto.
# 94: DB6605-010 tiene un precio de: 17,47 €
# 95: DB6924-350 tiene un precio de: 38,97 €
# 96: DB7797-014 tiene un precio de: 54,97 €
# 97: DB8149-817 tiene un precio de: No se ha podido obtener el precio para este producto.
# 98: DB8521-663 tiene un precio de: No se ha podido obtener el precio para este producto.
# 99: DB9953-202 tiene un precio de: No se ha podido obtener el precio para este producto.
# 100: DB9975-010 tiene un precio de: 22,99 €
# 101: DB9975-100 tiene un precio de: 22,99 €
# 102: DC0480-001 tiene un precio de: No se ha podido obtener el precio para este producto.
# 103: DC0481-008 tiene un precio de: 47,97 €
# 104: DC0481-010 tiene un precio de: 47,97 €
# 105: DC0481-500 tiene un precio de: 47,97 €
# 106: DC0620-100 tiene un precio de: 84,99 €
# 107: DC0621-010 tiene un precio de: 64,99 €
# 108: DC0621-100 tiene un precio de: 64,99 €
# 109: DC0734-621 tiene un precio de: No se ha podido obtener el precio para este producto.
# 110: DC0735-621 tiene un precio de: 38,97 €
# 111: DC0753-407 tiene un precio de: No se ha podido obtener el precio para este producto.
# 112: DC0774-020 tiene un precio de: No se ha podido obtener el precio para este producto.
# 113: DC0827-808 tiene un precio de: No se ha podido obtener el precio para este producto.
# 114: DC2096-010 tiene un precio de: 35,97 €
# 115: DC2380-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 116: DC2424-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 117: DC2533-001 tiene un precio de: 49,97 €
# 118: DC2533-102 tiene un precio de: No se ha podido obtener el precio para este producto.
# 119: DC2533-103 tiene un precio de: 49,97 €
# 120: DC2533-104 tiene un precio de: 109,99 €
# 121: DC2647-411 tiene un precio de: 29,99 €
# 122: DC2648-010 tiene un precio de: 19,99 €
# 123: DC3431-033 tiene un precio de: No se ha podido obtener el precio para este producto.
# 124: DC3432-002 tiene un precio de: 69,99 €
# 125: DC3432-008 tiene un precio de: 69,99 €
# 126: DC3432-125 tiene un precio de: 69,99 €
# 127: DC3432-402 tiene un precio de: 69,99 €
# 128: DC3579-005 tiene un precio de: 65,97 €
# 129: DC3579-006 tiene un precio de: 65,97 €
# 130: DC3580-531 tiene un precio de: No se ha podido obtener el precio para este producto.
# 131: DC3584-100 tiene un precio de: 149,99 €
# 132: DC3584-200 tiene un precio de: 149,99 €
# 133: DC3590-101 tiene un precio de: 139,99 €
# 134: DC3590-102 tiene un precio de: 129,99 €
# 135: DC3598-010 tiene un precio de: 19,99 €
# 136: DC3728-001 tiene un precio de: 64,99 €
# 137: DC3728-002 tiene un precio de: No se ha podido obtener el precio para este producto.
# 138: DC3728-003 tiene un precio de: 64,99 €
# 139: DC3728-004 tiene un precio de: 64,99 €
# 140: DC3728-005 tiene un precio de: No se ha podido obtener el precio para este producto.
# 141: DC3728-008 tiene un precio de: No se ha podido obtener el precio para este producto.
# 142: DC3728-014 tiene un precio de: 64,99 €
# 143: DC3728-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 144: DC3728-102 tiene un precio de: 64,99 €
# 145: DC3728-401 tiene un precio de: 64,99 €
# 146: DC3729-001 tiene un precio de: 64,99 €
# 147: DC3729-003 tiene un precio de: 64,99 €
# 148: DC3729-008 tiene un precio de: 47,97 €
# 149: DC3729-009 tiene un precio de: 59,99 €
# 150: DC3729-101 tiene un precio de: 64,99 €
# 151: DC3729-103 tiene un precio de: 64,99 €
# 152: DC3729-403 tiene un precio de: 59,99 €
# 153: DC3729-500 tiene un precio de: 64,99 €
# 154: DC3729-602 tiene un precio de: 59,99 €
# 155: DC4112-002 tiene un precio de: 112,47 €
# 156: DC4112-100 tiene un precio de: 112,47 €
# 157: DC4244-010 tiene un precio de: 32,99 €
# 158: DC4244-460 tiene un precio de: 26,97 €
# 159: DC4244-601 tiene un precio de: 26,97 €
# 160: DC4244-663 tiene un precio de: 32,99 €
# 161: DC4245-010 tiene un precio de: 19,99 €
# 162: DC4245-012 tiene un precio de: 19,99 €
# 163: DC5216-004 tiene un precio de: 84,99 €
# 164: DC5216-102 tiene un precio de: 47,97 €
# 165: DC5216-602 tiene un precio de: No se ha podido obtener el precio para este producto.
# 166: DC5320-004 tiene un precio de: 41,97 €
# 167: DC5320-010 tiene un precio de: 69,99 €
# 168: DC5320-652 tiene un precio de: 41,97 €
# 169: DC6078-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 170: DC6915-010 tiene un precio de: 49,99 €
# 171: DC6933-010 tiene un precio de: 47,99 €
# 172: DC6934-010 tiene un precio de: 47,99 €
# 173: DC6950-010 tiene un precio de: 47,99 €
# 174: DC7118-010 tiene un precio de: 49,99 €
# 175: DC7118-091 tiene un precio de: 49,99 €
# 176: DC7207-010 tiene un precio de: 39,99 €
# 177: DC7207-091 tiene un precio de: 39,99 €
# 178: DC7207-291 tiene un precio de: 39,99 €
# 179: DC7207-691 tiene un precio de: 27,97 €
# 180: DC7210-091 tiene un precio de: 30,47 €
# 181: DC7210-691 tiene un precio de: 42,99 €
# 182: DC7211-010 tiene un precio de: 39,99 €
# 183: DC7211-091 tiene un precio de: 39,99 €
# 184: DC7211-691 tiene un precio de: 31,47 €
# 185: DC7232-200 tiene un precio de: 109,99 €
# 186: DC7232-301 tiene un precio de: 109,99 €
# 187: DC7288-425 tiene un precio de: 38,47 €
# 188: DC7350-001 tiene un precio de: 159,99 €
# 189: DC7485-010 tiene un precio de: 29,99 €
# 190: DC7485-091 tiene un precio de: 29,99 €
# 191: DC7485-100 tiene un precio de: 29,99 €
# 192: DC7485-432 tiene un precio de: 25,47 €
# 193: DC7485-493 tiene un precio de: No se ha podido obtener el precio para este producto.
# 194: DC7485-680 tiene un precio de: 29,99 €
# 195: DC7485-687 tiene un precio de: 29,99 €
# 196: DC7485-705 tiene un precio de: 23,97 €
# 197: DC7537-901 tiene un precio de: No se ha podido obtener el precio para este producto.
# 198: DC7537-902 tiene un precio de: 13,99 €
# 199: DC7662-091 tiene un precio de: 35,97 €
# 200: DC7664-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 201: DC7664-091 tiene un precio de: 31,47 €
# 202: DC7672-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 203: DC7695-002 tiene un precio de: 84,99 €
# 204: DC7695-004 tiene un precio de: 84,99 €
# 205: DC7695-100 tiene un precio de: 84,99 €
# 206: DC7723-401 tiene un precio de: 159,99 €
# 207: DC7817-010 tiene un precio de: 32,99 €
# 208: DC7817-063 tiene un precio de: 26,47 €
# 209: DC7817-100 tiene un precio de: 32,99 €
# 210: DC7986-060 tiene un precio de: 99,99 €
# 211: DC8185-001 tiene un precio de: 79,99 €
# 212: DC8466-010 tiene un precio de: 79,99 €
# 213: DC8466-146 tiene un precio de: 79,99 €
# 214: DC8466-437 tiene un precio de: 79,99 €
# 215: DC8466-560 tiene un precio de: 79,99 €
# 216: DC8466-611 tiene un precio de: 79,99 €
# 217: DC8685-980 tiene un precio de: 17,99 €
# 218: DC8725-100 tiene un precio de: 74,99 €
# 219: DC8751-002 tiene un precio de: 79,97 €
# 220: DC8751-200 tiene un precio de: No se ha podido obtener el precio para este producto.
# 221: DC8892-001 tiene un precio de: No se ha podido obtener el precio para este producto.
# 222: DC8894-100 tiene un precio de: 119,99 €
# 223: DC8992-003 tiene un precio de: 64,99 €
# 224: DC8997-003 tiene un precio de: 59,99 €
# 225: DC8997-500 tiene un precio de: 59,99 €
# 226: DC8998-003 tiene un precio de: 64,99 €
# 227: DC8998-600 tiene un precio de: 59,99 €
# 228: DC9013-010 tiene un precio de: 49,99 €
# 229: DC9013-407 tiene un precio de: 29,97 €
# 230: DC9016-010 tiene un precio de: 32,47 €
# 231: DC9024-638 tiene un precio de: 47,97 €
# 232: DC9065-010 tiene un precio de: 99,99 €
# 233: DC9075-407 tiene un precio de: 35,97 €
# 234: DC9075-437 tiene un precio de: 38,97 €
# 235: DC9142-011 tiene un precio de: 59,99 €
# 236: DC9154-011 tiene un precio de: 54,99 €
# 237: DC9158-011 tiene un precio de: 54,99 €
# 238: DC9161-011 tiene un precio de: 19,99 €
# 239: DC9161-454 tiene un precio de: No se ha podido obtener el precio para este producto.
# 240: DC9165-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 241: DC9165-384 tiene un precio de: 22,99 €
# 242: DC9165-652 tiene un precio de: 22,99 €
# 243: DC9168-011 tiene un precio de: 59,99 €
# 244: DC9168-454 tiene un precio de: 59,99 €
# 245: DC9168-652 tiene un precio de: 59,99 €
# 246: DC9318-002 tiene un precio de: 50,97 €
# 247: DC9318-102 tiene un precio de: No se ha podido obtener el precio para este producto.
# 248: DC9318-104 tiene un precio de: 47,97 €
# 249: DC9319-102 tiene un precio de: 41,97 €
# 250: DC9319-104 tiene un precio de: 41,97 €
# 251: DC9413-001 tiene un precio de: 89,99 €
# 252: DC9413-003 tiene un precio de: 89,99 €
# 253: DC9454-001 tiene un precio de: 134,97 €
# 254: DC9486-100 tiene un precio de: 119,99 €
# 255: DC9486-101 tiene un precio de: 119,99 €
# 256: DC9829-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 257: DC9833-010 tiene un precio de: 34,99 €
# 258: DC9833-100 tiene un precio de: 26,47 €
# 259: DC9835-003 tiene un precio de: 42,99 €
# 260: DC9835-060 tiene un precio de: 34,47 €
# 261: DC9835-110 tiene un precio de: 34,47 €
# 262: DC9835-200 tiene un precio de: 42,99 €
# 263: DC9835-601 tiene un precio de: 25,97 €
# 264: DC9836-001 tiene un precio de: No se ha podido obtener el precio para este producto.
# 265: DC9836-002 tiene un precio de: 80,97 €
# 266: DC9836-004 tiene un precio de: 134,99 €
# 267: DC9836-100 tiene un precio de: 134,99 €
# 268: DC9836-200 tiene un precio de: 67,47 €
# 269: DC9836-400 tiene un precio de: 67,47 €
# 270: DC9836-600 tiene un precio de: 67,47 €
# 271: DC9968-010 tiene un precio de: 259,99 €
# 272: DC9968-446 tiene un precio de: 259,99 €
# 273: DC9993-001 tiene un precio de: No se ha podido obtener el precio para este producto.
# 274: DC9993-103 tiene un precio de: No se ha podido obtener el precio para este producto.
# 275: DC9993-601 tiene un precio de: No se ha podido obtener el precio para este producto.
# 276: DD0002-101 tiene un precio de: 19,99 €
# 277: DD0204-001 tiene un precio de: 79,99 €
# 278: DD0204-003 tiene un precio de: 79,99 €
# 279: DD0204-005 tiene un precio de: 79,99 €
# 280: DD0204-101 tiene un precio de: 79,99 €
# 281: DD0243-010 tiene un precio de: 34,99 €
# 282: DD0243-068 tiene un precio de: No se ha podido obtener el precio para este producto.
# 283: DD0243-223 tiene un precio de: 26,97 €
# 284: DD0243-460 tiene un precio de: No se ha podido obtener el precio para este producto.
# 285: DD0245-010 tiene un precio de: 34,99 €
# 286: DD0247-010 tiene un precio de: 34,99 €
# 287: DD0247-068 tiene un precio de: No se ha podido obtener el precio para este producto.
# 288: DD0249-334 tiene un precio de: 29,97 €
# 289: DD0249-460 tiene un precio de: No se ha podido obtener el precio para este producto.
# 290: DD0252-010 tiene un precio de: 49,99 €
# 291: DD0252-068 tiene un precio de: 39,99 €
# 292: DD0252-223 tiene un precio de: 27,97 €
# 293: DD0252-411 tiene un precio de: 27,97 €
# 294: DD0252-460 tiene un precio de: No se ha podido obtener el precio para este producto.
# 295: DD0252-491 tiene un precio de: 49,99 €
# 296: DD0252-667 tiene un precio de: No se ha podido obtener el precio para este producto.
# 297: DD0303-600 tiene un precio de: 45,47 €
# 298: DD0324-010 tiene un precio de: 54,99 €
# 299: DD0324-472 tiene un precio de: 54,99 €
# 300: DD0341-010 tiene un precio de: 38,97 €
# 301: DD0428-010 tiene un precio de: 49,99 €
# 302: DD0428-100 tiene un precio de: 49,99 €
# 303: DD0428-394 tiene un precio de: No se ha podido obtener el precio para este producto.
# 304: DD0428-460 tiene un precio de: 47,99 €
# 305: DD0428-494 tiene un precio de: No se ha podido obtener el precio para este producto.
# 306: DD0428-667 tiene un precio de: No se ha podido obtener el precio para este producto.
# 307: DD0428-690 tiene un precio de: No se ha podido obtener el precio para este producto.
# 308: DD0430-010 tiene un precio de: 64,99 €
# 309: DD0430-100 tiene un precio de: 64,99 €
# 310: DD0430-321 tiene un precio de: No se ha podido obtener el precio para este producto.
# 311: DD0430-424 tiene un precio de: No se ha podido obtener el precio para este producto.
# 312: DD0430-531 tiene un precio de: No se ha podido obtener el precio para este producto.
# 313: DD0430-610 tiene un precio de: No se ha podido obtener el precio para este producto.
# 314: DD0430-611 tiene un precio de: No se ha podido obtener el precio para este producto.
# 315: DD0430-657 tiene un precio de: No se ha podido obtener el precio para este producto.
# 316: DD0436-010 tiene un precio de: 69,99 €
# 317: DD0436-334 tiene un precio de: No se ha podido obtener el precio para este producto.
# 318: DD0436-610 tiene un precio de: No se ha podido obtener el precio para este producto.
# 319: DD0490-200 tiene un precio de: 77,97 €
# 320: DD0490-401 tiene un precio de: 77,97 €
# 321: DD0490-402 tiene un precio de: 77,97 €
# 322: DD0559-010 tiene un precio de: 34,99 €
# 323: DD0559-012 tiene un precio de: 34,99 €
# 324: DD0559-460 tiene un precio de: 26,97 €
# 325: DD0559-663 tiene un precio de: 34,99 €
# 326: DD0562-010 tiene un precio de: 34,99 €
# 327: DD0585-010 tiene un precio de: 54,99 €
# 328: DD0588-010 tiene un precio de: 59,99 €
# 329: DD0588-379 tiene un precio de: 32,97 €
# 330: DD0588-503 tiene un precio de: No se ha podido obtener el precio para este producto.
# 331: DD0593-010 tiene un precio de: 59,99 €
# 332: DD0593-379 tiene un precio de: 35,97 €
# 333: DD0615-010 tiene un precio de: 44,99 €
# 334: DD0618-010 tiene un precio de: 49,99 €
# 335: DD0618-379 tiene un precio de: 44,99 €
# 336: DD0620-010 tiene un precio de: 49,99 €
# 337: DD0623-010 tiene un precio de: 29,99 €
# 338: DD0623-100 tiene un precio de: 29,99 €
# 339: DD0626-010 tiene un precio de: 34,99 €
# 340: DD0626-073 tiene un precio de: 26,97 €
# 341: DD0626-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 342: DD0626-334 tiene un precio de: 23,97 €
# 343: DD0626-440 tiene un precio de: 34,99 €
# 344: DD0626-610 tiene un precio de: 23,97 €
# 345: DD0636-073 tiene un precio de: 29,99 €
# 346: DD0636-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 347: DD0638-010 tiene un precio de: 34,99 €
# 348: DD0638-073 tiene un precio de: 34,99 €
# 349: DD0638-100 tiene un precio de: 34,99 €
# 350: DD0638-334 tiene un precio de: 23,97 €
# 351: DD0641-010 tiene un precio de: 39,99 €
# 352: DD0641-073 tiene un precio de: 27,97 €
# 353: DD0782-011 tiene un precio de: 54,99 €
# 354: DD1068-001 tiene un precio de: No se ha podido obtener el precio para este producto.
# 355: DD1068-002 tiene un precio de: 129,99 €
# 356: DD1068-007 tiene un precio de: 129,99 €
# 357: DD1068-102 tiene un precio de: 129,99 €
# 358: DD1068-110 tiene un precio de: 77,97 €
# 359: DD1094-003 tiene un precio de: 39,99 €
# 360: DD1094-400 tiene un precio de: 39,99 €
# 361: DD1094-600 tiene un precio de: 39,99 €
# 362: DD1094-607 tiene un precio de: 34,99 €
# 363: DD1094-608 tiene un precio de: 39,99 €
# 364: DD1095-001 tiene un precio de: 44,99 €
# 365: DD1095-003 tiene un precio de: 44,99 €
# 366: DD1095-007 tiene un precio de: 44,99 €
# 367: DD1095-300 tiene un precio de: 35,97 €
# 368: DD1095-400 tiene un precio de: 44,99 €
# 369: DD1095-500 tiene un precio de: 39,99 €
# 370: DD1095-608 tiene un precio de: 44,99 €
# 371: DD1096-003 tiene un precio de: 54,99 €
# 372: DD1096-007 tiene un precio de: 54,99 €
# 373: DD1096-300 tiene un precio de: 39,97 €
# 374: DD1096-400 tiene un precio de: 54,99 €
# 375: DD1096-500 tiene un precio de: 49,99 €
# 376: DD1096-600 tiene un precio de: 54,99 €
# 377: DD1096-608 tiene un precio de: 54,99 €
# 378: DD1101-646 tiene un precio de: No se ha podido obtener el precio para este producto.
# 379: DD1113-003 tiene un precio de: 54,99 €
# 380: DD1113-006 tiene un precio de: 42,47 €
# 381: DD1113-608 tiene un precio de: 54,99 €
# 382: DD1114-003 tiene un precio de: 44,99 €
# 383: DD1114-006 tiene un precio de: 35,97 €
# 384: DD1114-608 tiene un precio de: 44,99 €
# 385: DD1117-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 386: DD1139-574 tiene un precio de: No se ha podido obtener el precio para este producto.
# 387: DD1154-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 388: DD1205-010 tiene un precio de: 49,99 €
# 389: DD1328-010 tiene un precio de: 27,99 €
# 390: DD1328-100 tiene un precio de: 25,47 €
# 391: DD1328-334 tiene un precio de: 27,99 €
# 392: DD1391-103 tiene un precio de: No se ha podido obtener el precio para este producto.
# 393: DD1399-105 tiene un precio de: No se ha podido obtener el precio para este producto.
# 394: DD1399-401 tiene un precio de: 119,99 €
# 395: DD1399-600 tiene un precio de: 119,99 €
# 396: DD1399-700 tiene un precio de: No se ha podido obtener el precio para este producto.
# 397: DD1432-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 398: DD1503-109 tiene un precio de: No se ha podido obtener el precio para este producto.
# 399: DD1503-200 tiene un precio de: No se ha podido obtener el precio para este producto.
# 400: DD1503-602 tiene un precio de: 109,99 €
# 401: DD1579-400 tiene un precio de: 159,99 €
# 402: DD1646-026 tiene un precio de: 79,99 €
# 403: DD1698-091 tiene un precio de: 31,47 €
# 404: DD1700-010 tiene un precio de: 74,99 €
# 405: DD1700-068 tiene un precio de: 74,99 €
# 406: DD1700-638 tiene un precio de: No se ha podido obtener el precio para este producto.
# 407: DD1705-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 408: DD1726-469 tiene un precio de: No se ha podido obtener el precio para este producto.
# 409: DD1748-084 tiene un precio de: 34,99 €
# 410: DD1869-103 tiene un precio de: No se ha podido obtener el precio para este producto.
# 411: DD1869-601 tiene un precio de: 119,99 €
# 412: DD1873-102 tiene un precio de: No se ha podido obtener el precio para este producto.
# 413: DD1887-010 tiene un precio de: 32,99 €
# 414: DD1911-010 tiene un precio de: 34,99 €
# 415: DD1913-010 tiene un precio de: 39,99 €
# 416: DD1913-068 tiene un precio de: 39,99 €
# 417: DD1913-451 tiene un precio de: 31,97 €
# 418: DD1917-010 tiene un precio de: 34,99 €
# 419: DD1917-068 tiene un precio de: 34,99 €
# 420: DD1917-100 tiene un precio de: 34,99 €
# 421: DD1917-451 tiene un precio de: 29,97 €
# 422: DD1919-010 tiene un precio de: 39,99 €
# 423: DD1919-068 tiene un precio de: 39,99 €
# 424: DD1986-010 tiene un precio de: 39,99 €
# 425: DD1986-100 tiene un precio de: 39,99 €
# 426: DD1988-010 tiene un precio de: 34,99 €
# 427: DD1988-068 tiene un precio de: 34,99 €
# 428: DD1988-100 tiene un precio de: 34,99 €
# 429: DD1990-010 tiene un precio de: 39,99 €
# 430: DD1990-068 tiene un precio de: 39,99 €
# 431: DD1990-100 tiene un precio de: 39,99 €
# 432: DD1990-451 tiene un precio de: 39,99 €
# 433: DD1990-480 tiene un precio de: 39,99 €
# 434: DD1990-657 tiene un precio de: 39,99 €
# 435: DD1992-010 tiene un precio de: 34,99 €
# 436: DD1992-100 tiene un precio de: 34,99 €
# 437: DD1992-451 tiene un precio de: 34,99 €
# 438: DD2122-010 tiene un precio de: 89,99 €
# 439: DD2122-068 tiene un precio de: 89,99 €
# 440: DD2122-326 tiene un precio de: 53,97 €
# 441: DD2124-010 tiene un precio de: 104,99 €
# 442: DD2124-068 tiene un precio de: 104,99 €
# 443: DD2136-010 tiene un precio de: 50,97 €
# 444: DD2314-004 tiene un precio de: No se ha podido obtener el precio para este producto.
# 445: DD2314-006 tiene un precio de: 79,99 €
# 446: DD2314-109 tiene un precio de: 79,99 €
# 447: DD2314-110 tiene un precio de: 79,99 €
# 448: DD2314-111 tiene un precio de: 79,99 €
# 449: DD2858-001 tiene un precio de: 224,99 €
# 450: DD2975-100 tiene un precio de: 94,99 €
# 451: DD3024-001 tiene un precio de: 169,99 €
# 452: DD3024-005 tiene un precio de: 159,99 €
# 453: DD3024-008 tiene un precio de: No se ha podido obtener el precio para este producto.
# 454: DD3024-301 tiene un precio de: No se ha podido obtener el precio para este producto.
# 455: DD3024-600 tiene un precio de: 95,97 €
# 456: DD3055-010 tiene un precio de: 27,99 €
# 457: DD3055-635 tiene un precio de: 24,99 €
# 458: DD3111-100 tiene un precio de: 65,97 €
# 459: DD3111-101 tiene un precio de: 65,97 €
# 460: DD3111-102 tiene un precio de: 109,99 €
# 461: DD3697-001 tiene un precio de: 72,47 €
# 462: DD3782-712 tiene un precio de: 47,99 €
# 463: DD4005-654 tiene un precio de: 27,99 €
# 464: DD4576-084 tiene un precio de: 39,99 €
# 465: DD4618-646 tiene un precio de: No se ha podido obtener el precio para este producto.
# 466: DD4732-206 tiene un precio de: No se ha podido obtener el precio para este producto.
# 467: DD4746-010 tiene un precio de: 79,99 €
# 468: DD4754-010 tiene un precio de: 32,47 €
# 469: DD4756-010 tiene un precio de: 64,99 €
# 470: DD4756-084 tiene un precio de: 64,99 €
# 471: DD4756-451 tiene un precio de: 64,99 €
# 472: DD4894-010 tiene un precio de: 64,99 €
# 473: DD4894-084 tiene un precio de: 38,97 €
# 474: DD4894-309 tiene un precio de: 64,99 €
# 475: DD4921-010 tiene un precio de: 49,99 €
# 476: DD4921-379 tiene un precio de: No se ha podido obtener el precio para este producto.
# 477: DD4927-010 tiene un precio de: 49,99 €
# 478: DD4941-010 tiene un precio de: 29,99 €
# 479: DD4941-073 tiene un precio de: 29,99 €
# 480: DD4941-100 tiene un precio de: No se ha podido obtener el precio para este producto.
# 481: DD4941-334 tiene un precio de: No se ha podido obtener el precio para este producto.
# 482: DD4941-569 tiene un precio de: 24,99 €
# 483: DD4945-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 484: DD4945-334 tiene un precio de: 59,99 €
# 485: DD5003-010 tiene un precio de: 64,99 €
# 486: DD5003-084 tiene un precio de: 64,99 €
# 487: DD5110-273 tiene un precio de: No se ha podido obtener el precio para este producto.
# 488: DD5116-010 tiene un precio de: 74,97 €
# 489: DD5116-206 tiene un precio de: 74,97 €
# 490: DD5118-010 tiene un precio de: 74,99 €
# 491: DD5135-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 492: DD5174-010 tiene un precio de: 65,97 €
# 493: DD5174-063 tiene un precio de: 65,97 €
# 494: DD5475-010 tiene un precio de: 49,99 €
# 495: DD5597-638 tiene un precio de: 35,97 €
# 496: DD5626-010 tiene un precio de: 47,97 €
# 497: DD5632-126 tiene un precio de: No se ha podido obtener el precio para este producto.
# 498: DD5634-010 tiene un precio de: 69,99 €
# 499: DD5636-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 500: DD5636-126 tiene un precio de: No se ha podido obtener el precio para este producto.
# 501: DD5642-200 tiene un precio de: 21,47 €
# 502: DD5644-010 tiene un precio de: 114,99 €
# 503: DD5644-638 tiene un precio de: 68,97 €
# 504: DD5647-010 tiene un precio de: 94,99 €
# 505: DD5647-638 tiene un precio de: 56,97 €
# 506: DD5649-010 tiene un precio de: 74,99 €
# 507: DD5662-010 tiene un precio de: 84,99 €
# 508: DD5662-084 tiene un precio de: 84,99 €
# 509: DD5662-309 tiene un precio de: 84,99 €
# 510: DD5667-010 tiene un precio de: 219,99 €
# 511: DD5695-010 tiene un precio de: 164,99 €
# 512: DD5852-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 513: DD5880-100 tiene un precio de: 24,47 €
# 514: DD5882-010 tiene un precio de: 39,99 €
# 515: DD5882-100 tiene un precio de: 39,99 €
# 516: DD5921-010 tiene un precio de: 29,99 €
# 517: DD5921-811 tiene un precio de: No se ha podido obtener el precio para este producto.
# 518: DD5927-010 tiene un precio de: 39,99 €
# 519: DD5927-100 tiene un precio de: 39,99 €
# 520: DD5927-811 tiene un precio de: 34,99 €
# 521: DD5935-010 tiene un precio de: 39,99 €
# 522: DD5935-811 tiene un precio de: 27,97 €
# 523: DD5940-010 tiene un precio de: 34,99 €
# 524: DD5940-394 tiene un precio de: No se ha podido obtener el precio para este producto.
# 525: DD5940-811 tiene un precio de: No se ha podido obtener el precio para este producto.
# 526: DD5975-010 tiene un precio de: 69,99 €
# 527: DD5975-200 tiene un precio de: No se ha podido obtener el precio para este producto.
# 528: DD5975-397 tiene un precio de: No se ha podido obtener el precio para este producto.
# 529: DD6061-010 tiene un precio de: 104,99 €
# 530: DD6061-460 tiene un precio de: 62,97 €
# 531: DD6061-503 tiene un precio de: 62,97 €
# 532: DD6063-010 tiene un precio de: 154,99 €
# 533: DD6063-460 tiene un precio de: No se ha podido obtener el precio para este producto.
# 534: DD6084-010 tiene un precio de: 84,99 €
# 535: DD6130-010 tiene un precio de: 32,97 €
# 536: DD6203-001 tiene un precio de: 99,99 €
# 537: DD6203-009 tiene un precio de: 99,99 €
# 538: DD6215-010 tiene un precio de: 74,99 €
# 539: DD6229-010 tiene un precio de: 89,99 €
# 540: DD6229-326 tiene un precio de: 53,97 €
# 541: DD6278-010 tiene un precio de: 24,99 €
# 542: DD6278-077 tiene un precio de: 24,99 €
# 543: DD6302-010 tiene un precio de: 41,97 €
# 544: DD6302-077 tiene un precio de: No se ha podido obtener el precio para este producto.
# 545: DD6478-010 tiene un precio de: 24,47 €
# 546: DD6478-507 tiene un precio de: 34,99 €
# 547: DD6478-609 tiene un precio de: 24,47 €
# 548: DD6478-621 tiene un precio de: 24,47 €
# 549: DD6482-010 tiene un precio de: 24,99 €
# 550: DD6482-077 tiene un precio de: 24,99 €
# 551: DD6612-001 tiene un precio de: 189,99 €
# 552: DD6700-010 tiene un precio de: 44,97 €
# 553: DD6799-010 tiene un precio de: 84,99 €
# 554: DD6799-800 tiene un precio de: 47,97 €
# 555: DD6835-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 556: DD6835-610 tiene un precio de: 29,97 €
# 557: DD6841-010 tiene un precio de: No se ha podido obtener el precio para este producto.
# 558: DD6857-480 tiene un precio de: 59,97 €
# 559: DD6869-010 tiene un precio de: 44,97 €
# 560: DD6869-355 tiene un precio de: 44,97 €
# 561: DD6869-480 tiene un precio de: 44,97 €
# 562: DD6958-001 tiene un precio de: 189,99 €
# 563: DD6958-060 tiene un precio de: 184,99 €
# 564: DD6958-065 tiene un precio de: 110,97 €
# 565: DD6958-091 tiene un precio de: 184,99 €
# 566: DD6958-108 tiene un precio de: 184,99 €
# 567: DD6998-063 tiene un precio de: No se ha podido obtener el precio para este producto.
# 568: DD7001-011 tiene un precio de: No se ha podido obtener el precio para este producto.
# 569: DD7302-004 tiene un precio de: 47,99 €
# 570: DD7302-005 tiene un precio de: 47,99 €
# 571: DD7303-004 tiene un precio de: 54,99 €
# 572: DD7303-005 tiene un precio de: 54,99 €
# 573: DD7303-012 tiene un precio de: No se ha podido obtener el precio para este producto.
# 574: DD7473-010 tiene un precio de: 39,99 €
# 575: DD7473-691 tiene un precio de: No se ha podido obtener el precio para este producto.
# 576: DD7617-010 tiene un precio de: 42,99 €
# 577: DD7617-334 tiene un precio de: 27,97 €
# 578: DD7639-100 tiene un precio de: 27,99 €
